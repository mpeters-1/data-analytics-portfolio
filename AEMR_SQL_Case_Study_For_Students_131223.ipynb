# %% [markdown]
# <center><h1 style="color:#D4AF37"> ⚡⚡ AEMR Data Analysis ⚡⚡</h1>

# %% [markdown]
# <img src = "https://images.squarespace-cdn.com/content/v1/551972d8e4b0d571edc2e2c8/8f3abd33-0916-4415-9b24-593eea1d1e3c/Screen+Shot+2022-04-20+at+12.41.24+PM.png">
#
#
# It’s time for you to apply your budding SQL Competencies to analyse data for the American Energy Market Regulator (AEMR).
#
# The analytics team has supplied you with the following table extract that contains all the data you need to analyse for the `AEMR` outages.
#
# `AEMR_Outage_Table`
#
# Now let's revisit the business problem below and understand what we're seeking to solve.

# %% [markdown]
# <h1 style="color:#D4AF37"> What's the Business Problem? 💰</h1>
#
# The American Energy Market Regulator (AEMR) is responsible for looking after the
# United States of America’s domestic energy network. The regulator’s responsibility is to
# ensure that America’s energy network remains reliable with minimal disruptions, which
# are known as outages.
#
# There are four key types of outages:
#
# ● Consequential
#
# ● Forced
#
# ● Opportunistic
#
# ● Planned
#
# Recently, the AEMR management team has been increasingly aware of a large number
# of energy providers that submitted outages over the 2016 and 2017 calendar years. The
# management team has expressed a desire to have the following two areas of concern
# addressed:
#
# <b> A) Energy Stability and Market Outages
#     <p>
# B) Energy Losses and Market Reliability </b>
#
# As an analyst within the data and reporting team, you have been asked to address these
# two immediate areas of concern. Feel free to also explore beyond the queries asked and provide additional insights that you feel may be of interest to the management team.

# %% [markdown]
# <h3 style="color:#D4AF37">  SQLite Refresher ⚙️ </h3>
#
# We've pre-loaded the data you need to access in the `AEMR.db` we've included. We'll have you write SQL below where all your SQL queries will be stored in this notebook as a reference you can use when you review your data analysis in Tableau. </b>.
#
# To load the `AEMR.db` file into this notebook, run the below cells.
#
# <b> ⚠️ Please remember that everytime you close this file and re-open this, you'll need to re-run the cells below. ⚠️ </b>

# %% [markdown]
# <b>⚠️ Note: Remember, you'll need to start each cell with the **`%%sql`** line, which allows us to execute SQL from within this notebook.</b>

# %%
# !pip install ipython-sql
# !pip install prettytable==3.12
# Out:
# Requirement already satisfied: ipython-sql in /opt/anaconda3/lib/python3.13/site-packages (0.5.0)
# Requirement already satisfied: prettytable in /opt/anaconda3/lib/python3.13/site-packages (from ipython-sql) (3.12.0)
# Requirement already satisfied: ipython in /opt/anaconda3/lib/python3.13/site-packages (from ipython-sql) (8.30.0)
# Requirement already satisfied: sqlalchemy>=2.0 in /opt/anaconda3/lib/python3.13/site-packages (from ipython-sql) (2.0.39)
# Requirement already satisfied: sqlparse in /opt/anaconda3/lib/python3.13/site-packages (from ipython-sql) (0.5.3)
# Requirement already satisfied: six in /opt/anaconda3/lib/python3.13/site-packages (from ipython-sql) (1.17.0)
# Requirement already satisfied: ipython-genutils in /opt/anaconda3/lib/python3.13/site-packages (from ipython-sql) (0.2.0)
# Requirement already satisfied: typing-extensions>=4.6.0 in /opt/anaconda3/lib/python3.13/site-packages (from sqlalchemy>=2.0->ipython-sql) (4.12.2)
# Requirement already satisfied: decorator in /opt/anaconda3/lib/python3.13/site-packages (from ipython->ipython-sql) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in /opt/anaconda3/lib/python3.13/site-packages (from ipython->ipython-sql) (0.19.2)
# Requirement already satisfied: matplotlib-inline in /opt/anaconda3/lib/python3.13/site-packages (from ipython->ipython-sql) (0.1.6)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in /opt/anaconda3/lib/python3.13/site-packages (from ipython->ipython-sql) (3.0.43)
# Requirement already satisfied: pygments>=2.4.0 in /opt/anaconda3/lib/python3.13/site-packages (from ipython->ipython-sql) (2.19.1)
# Requirement already satisfied: stack-data in /opt/anaconda3/lib/python3.13/site-packages (from ipython->ipython-sql) (0.2.0)
# Requirement already satisfied: traitlets>=5.13.0 in /opt/anaconda3/lib/python3.13/site-packages (from ipython->ipython-sql) (5.14.3)
# Requirement already satisfied: pexpect>4.3 in /opt/anaconda3/lib/python3.13/site-packages (from ipython->ipython-sql) (4.8.0)
# Requirement already satisfied: wcwidth in /opt/anaconda3/lib/python3.13/site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython->ipython-sql) (0.2.5)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /opt/anaconda3/lib/python3.13/site-packages (from jedi>=0.16->ipython->ipython-sql) (0.8.4)
# Requirement already satisfied: ptyprocess>=0.5 in /opt/anaconda3/lib/python3.13/site-packages (from pexpect>4.3->ipython->ipython-sql) (0.7.0)
# Requirement already satisfied: executing in /opt/anaconda3/lib/python3.13/site-packages (from stack-data->ipython->ipython-sql) (0.8.3)
# Requirement already satisfied: asttokens in /opt/anaconda3/lib/python3.13/site-packages (from stack-data->ipython->ipython-sql) (3.0.0)
# Requirement already satisfied: pure-eval in /opt/anaconda3/lib/python3.13/site-packages (from stack-data->ipython->ipython-sql) (0.2.2)
# Requirement already satisfied: prettytable==3.12 in /opt/anaconda3/lib/python3.13/site-packages (3.12.0)
# Requirement already satisfied: wcwidth in /opt/anaconda3/lib/python3.13/site-packages (from prettytable==3.12) (0.2.5)

# %%
import requests
from IPython.core.magic import register_line_magic
from IPython.display import HTML
import sqlite3

@register_line_magic
def load_sqlite_db(url):
    response = requests.get(url)

    if response.status_code == 200:
        with open('temp_db_file.db', 'wb') as file:
            file.write(response.content)
        print('SQLite database file downloaded successfully.')
    else:
        print('Failed to download the SQLite database file.')

sqlite_db_url = 'https://raw.githubusercontent.com/chrishuisb1990/practice_datasets/main/AEMR.db'

# %load_sqlite_db $sqlite_db_url

# %load_ext sql

# %sql sqlite:///temp_db_file.db

# %config SqlMagic.style = '_DEPRECATED_DEFAULT'
# Out:
# SQLite database file downloaded successfully.

# %% [markdown]
# We've included an example of how you would write a query against the database below:
#
# ~~~sql
# %%sql
# SELECT
# *
# FROM AEMR_Outage_Table
# LIMIT 10
# ~~~
#
# Once you've written your SQL, you'll then need to press `Ctrl` + `Enter` to run the cell.
# Otherwise, you can just press `run` at the very top of your screen, to run the specific cell.
#
# For your convenience, we've included a <b style = "color:#5D3FD3"> subset of the answers </b> under the header `Expected Output (Sample)`. These small subsets also include all the `columns` you'll need to include in your Query, so you know what to expect!
#
# Good luck!
#
# <b>PS: In case any of you get stuck regarding how to tackle any of the questions, we've included a breakdown <a href = "https://drive.google.com/file/d/1sXBGV5MZooZ7L38WYyXf9lIaA5sdKL7X/view?usp=share_link"> here</a> where Chris walks through how to tackle each question! Feel free to use this when you're stuck and you can't book a Mentor Call! </b>

# %% [markdown]
# <h3 style="color:#D4AF37"> ⚡ Part I. Energy Stability & Market Outages ⚡ </h3>
#
# Energy stability is one of the key themes the AEMR management team cares about. To ensure energy security and reliability, AEMR needs to understand the following:
# <p>
# <b>
#
# <li> What are the most common outage types and how long do they tend to last?
# <li> How frequently do the outages occur?
# <li> Are there any energy providers which have more outages than their peers which may be indicative of being unreliable?
#
# <p>
#
# <u style="color:Maroon"> Please note that throughout the entire case study, we are interested ONLY in the Outages where Status = Approved. We don't have any interest in Outages that were cancelled or not approved. This means your WHERE Clause will ALWAYS contain the field `Where Status = Approved` </u>

# %% [markdown]
# <h3 style="color:#D4AF37"> Question One </h3>
#
# <b> Write a SQL Statement to `COUNT` the number of valid (i.e. `Status = Approved`) Outage Events sorted by their respective `Outage_Reason` (i.e. `Forced`, `Consequential`, `Scheduled`, `Opportunistic`) over the 2016 & 2017 Periods. </b>
#
# Do we notice anything regarding the trends for specific Outages over the 2016 / 2017 Period?

# %% [markdown]
# <h4 style="color:Teal"> Please write your SQL in the code window below </h4>

# %% [markdown]
# <b>⚠️ Note: Remember, you'll need to start each cell with the **`%%sql`** line, which allows us to execute SQL from within this notebook.</b>

# %%
# %%sql
# SELECT
# *
# FROM AEMR_Outage_Table
# LIMIT 10;
# Out:
#  * sqlite:///temp_db_file.db
# Done.
# [(1, '2017-12-28 06:00', '2017-12-28 10:00', 2017, 12, 'DNHR_DENMARK_WF1', 'DNHR', 'Approved', 'Consequential', 1.44, 'a network outage in Denmark caused the windfarm to trip at 6:26 am'),
#  (2, '2017-12-26 09:00', '2017-12-27 00:00', 2017, 12, 'COLLGAR_WF1', 'COLLGAR', 'Approved', 'Forced', 30.0, 'Forced Outage - BS on Overhead line pole S-81 - CG10/11'),
#  (3, '2017-12-31 09:00', '2017-12-31 09:00', 2017, 12, 'AURICON_PNJ_U1', 'AURICON', 'Approved', 'Forced', 5.702999999999999, 'Under generation - ambient conditions'),
#  (4, '2017-12-31 08:30', '2017-12-31 08:30', 2017, 12, 'AURICON_PNJ_U1', 'AURICON', 'Approved', 'Forced', 5.085, 'Under generation - ambient conditions'),
#  (5, '2017-12-31 08:00', '2017-12-31 08:00', 2017, 12, 'AURICON_PNJ_U1', 'AURICON', 'Approved', 'Forced', 5.02, 'Under generation - ambient conditions'),
#  (6, '2017-12-30 23:30', '2017-12-30 23:30', 2017, 12, 'AURICON_PNJ_U1', 'AURICON', 'Approved', 'Forced', 5.79, 'Under generation - ambient conditions'),
#  (7, '2017-12-30 23:00', '2017-12-30 23:00', 2017, 12, 'AURICON_PNJ_U1', 'AURICON', 'Approved', 'Forced', 5.412000000000001, 'Under generation - ambient conditions'),
#  (8, '2017-12-30 22:30', '2017-12-30 22:30', 2017, 12, 'AURICON_PNJ_U1', 'AURICON', 'Approved', 'Forced', 4.735, 'Under generation - ambient conditions'),
#  (9, '2017-12-29 23:30', '2017-12-29 23:30', 2017, 12, 'AURICON_PNJ_U1', 'AURICON', 'Approved', 'Forced', 4.245, 'Under generation - ambient conditions'),
#  (10, '2017-12-29 23:00', '2017-12-29 23:00', 2017, 12, 'AURICON_PNJ_U1', 'AURICON', 'Approved', 'Forced', 3.9619999999999997, 'Under generation - ambient conditions')]

# %%
# %%sql
# --Question One Response
# SELECT
# year,
# outage_reason,
# COUNT(status) AS Valid_Outage_Events
# FROM AEMR_Outage_Table
# WHERE status = 'Approved'
#     AND year = '2016'
# GROUP BY outage_reason
# ORDER BY outage_reason;
# Out:
#  * sqlite:///temp_db_file.db
# Done.
# [(2016, 'Consequential', 181),
#  (2016, 'Forced', 1264),
#  (2016, 'Opportunistic Maintenance (Planned)', 106),
#  (2016, 'Scheduled (Planned)', 380)]

# %% [markdown]
# <h3 style = "color:#5D3FD3"> Expected Output (Sample) </h3>

# %%
# Out:
#  * sqlite:///AEMR.db
# Done.
# [(181, 'Consequential', 2016),
#  (1264, 'Forced', 2016),
#  (106, 'Opportunistic Maintenance (Planned)', 2016),
#  (380, 'Scheduled (Planned)', 2016)]

# %% [markdown]
# Now how about examining some monthly trends? Do we note any behaviours across the months that indicate certain months having more reliability issues over other months?

# %% [markdown]
# <h3 style="color:#D4AF37"> Question Two </h3>

# %% [markdown]
# <b> i) Write a SQL Statement showing the `Total` of all Outage Types (Forced, Consequential, Scheduled, Opportunistic) where the `Status = Approved`, that occurred for both 2016 and 2017, grouped by `Year` and `Month`.  per month (i.e. 1 – 12). Order by `Year`, `Month`, `Total_Number_Outages` in Descending Order.
#
#
# ii) Building on the query you write in i), group the results by `Outage Type`, `Year` and `Month`. This is so you can identify whether there is any outage type specifically increasing on a monthly basis when comparing 2016 to 2017. </b>
#
#
# <b>⚠️Hint: You might find it helpful to create a small Common Table Expression to address these two questions! </b>

# %% [markdown]
# <h4 style="color:Teal"> Please write your SQL in the code window below </h4>

# %%
# %%sql
# --Question Two Response
# SELECT
# year,
# month,
# COUNT(status) AS total_number_outages
# FROM AEMR_Outage_Table
# WHERE status = 'Approved'
#     AND (year = 2016
#     OR year = 2017)
# GROUP BY year, month
# ORDER BY year, month, total_number_outages DESC;
# Out:
#  * sqlite:///temp_db_file.db
# Done.
# [(2016, 1, 191),
#  (2016, 2, 227),
#  (2016, 3, 136),
#  (2016, 4, 134),
#  (2016, 5, 174),
#  (2016, 6, 168),
#  (2016, 7, 147),
#  (2016, 8, 194),
#  (2016, 9, 124),
#  (2016, 10, 124),
#  (2016, 11, 200),
#  (2016, 12, 112),
#  (2017, 1, 103),
#  (2017, 2, 150),
#  (2017, 3, 109),
#  (2017, 4, 127),
#  (2017, 5, 166),
#  (2017, 6, 204),
#  (2017, 7, 210),
#  (2017, 8, 209),
#  (2017, 9, 172),
#  (2017, 10, 276),
#  (2017, 11, 197),
#  (2017, 12, 248)]

# %% [markdown]
# <h3 style = "color:#5D3FD3"> Expected Output (Sample) </h3>

# %%
# Out:
#  * sqlite:///AEMR.db
# Done.
# [(2016, 1, 191),
#  (2016, 2, 227),
#  (2016, 3, 136),
#  (2016, 4, 134),
#  (2016, 5, 174)]

# %% [markdown]
# Hmm. Interesting. We've now identified a specific outage type is rapidly increasing from 2016 to 2017. However, frequency is just one aspect we care about. We also care about the <b> `duration` </b> of our ouatges.
#
# In other words, if an outage is very short, we aren't as concerned. However, if the outage is very long, this then has the risk of threatening our energy supplies. We want to identify the problematic energy providers here. This leads us to our next question below.

# %% [markdown]
# <h3 style="color:#D4AF37"> Question Three </h3>

# %% [markdown]
# <b>Write a SQL statement that calculates 1) The `Total_Number_Outage_Events` and 2) The <b> `Average Duration`</b> in <u>DAYS</u> for each `Participant Code` and `Outage Type` over the 2016 and 2017 Period where the `Status = Approved`.
# Order by `Total_Number_Outage_Events` in Descending Order, `Reason` and `Year`.
#
# Please note the average duration in days should be rounded to 2 decimal places for ease of comparison. When calculating the average duration, please note that you'll need to use the following fields:
#
# `Start_Time` and `End_Time`. </b>
#
# <b>⚠️ Hint:</b> If you're not sure how to calculate the difference between the `start_time` and `end_time` , reference this link <a href ="https://learnsql.com/cookbook/how-to-calculate-the-difference-between-two-timestamps-in-sqlite/"> here </a>
#
# We've included an example below of how you could use the `JULIANDAY()` function! Remember, the `JULIANDAY()` function returns the results in days, including the fractional component. Some of the date(s) are flipped in the dataset, so you'll need to use the ABS() function to ensure you don't return any negative values!
#
# ~~~sql
# %%sql
#
# SELECT
#         AVG((ABS(JULIANDAY(Date_2) - JULIANDAY(Date1)))
# FROM Some_Database
# ~~~

# %% [markdown]
# <h4 style="color:Teal"> Please write your SQL in the code window below </h4>

# %%
# %%sql
# --Question Three Response
# SELECT
# year,
# participant_code,
# outage_reason,
# ROUND(AVG(ABS(JULIANDAY(end_time) - JULIANDAY(start_time))), 2) AS avg_duration_days,
# COUNT(status) AS total_number_outage_events
# FROM AEMR_Outage_Table
# WHERE status = 'Approved'
#     AND (year = 2016
#     OR year = 2017)
# GROUP BY participant_code, year, month
# ORDER BY total_number_outage_events DESC, outage_reason, year;
# Out:
#  * sqlite:///temp_db_file.db
# Done.
# [(2017, 'AURICON', 'Forced', 0.14, 125),
#  (2016, 'GW', 'Forced', 0.61, 110),
#  (2017, 'AURICON', 'Forced', 0.14, 95),
#  (2017, 'AURICON', 'Forced', 0.24, 86),
#  (2017, 'GW', 'Forced', 0.41, 67),
#  (2016, 'AURICON', 'Forced', 0.19, 63),
#  (2016, 'GW', 'Forced', 0.4, 55),
#  (2016, 'GW', 'Forced', 0.44, 52),
#  (2017, 'AURICON', 'Forced', 0.25, 52),
#  (2017, 'GW', 'Forced', 0.03, 50),
#  (2017, 'AURICON', 'Forced', 0.12, 45),
#  (2016, 'MELK', 'Forced', 0.92, 42),
#  (2016, 'AURICON', 'Forced', 0.04, 42),
#  (2017, 'MELK', 'Forced', 1.94, 41),
#  (2016, 'PMC', 'Scheduled (Planned)', 0.29, 39),
#  (2016, 'MELK', 'Forced', 2.6, 38),
#  (2016, 'AUXC', 'Forced', 0.0, 38),
#  (2016, 'GW', 'Consequential', 2.52, 35),
#  (2016, 'MELK', 'Forced', 1.93, 34),
#  (2016, 'AURICON', 'Forced', 0.13, 33),
#  (2017, 'PUG', 'Forced', 0.02, 33),
#  (2016, 'AURICON', 'Forced', 0.19, 32),
#  (2016, 'AURICON', 'Forced', 0.3, 32),
#  (2017, 'TRMOS', 'Forced', 0.07, 32),
#  (2017, 'TRMOS', 'Forced', 0.29, 31),
#  (2017, 'AUXC', 'Forced', 0.0, 31),
#  (2016, 'GW', 'Forced', 1.15, 30),
#  (2017, 'AURICON', 'Forced', 0.15, 30),
#  (2016, 'PJRH', 'Opportunistic Maintenance (Planned)', 1.02, 30),
#  (2016, 'MELK', 'Forced', 1.43, 29),
#  (2016, 'AUXC', 'Forced', 0.07, 29),
#  (2017, 'MELK', 'Forced', 1.76, 29),
#  (2017, 'MELK', 'Forced', 3.36, 29),
#  (2017, 'AURICON', 'Forced', 0.35, 29),
#  (2017, 'AURICON', 'Forced', 0.25, 29),
#  (2017, 'MELK', 'Forced', 1.93, 28),
#  (2017, 'MELK', 'Forced', 11.67, 28),
#  (2017, 'AURICON', 'Forced', 0.07, 28),
#  (2016, 'AUXC', 'Consequential', 0.25, 27),
#  (2017, 'MELK', 'Forced', 1.6, 27),
#  (2016, 'MELK', 'Forced', 0.99, 26),
#  (2016, 'GW', 'Opportunistic Maintenance (Planned)', 0.98, 26),
#  (2016, 'MELK', 'Forced', 3.42, 24),
#  (2016, 'GW', 'Forced', 0.74, 24),
#  (2017, 'AURICON', 'Forced', 0.22, 24),
#  (2017, 'PJRH', 'Opportunistic Maintenance (Planned)', 0.36, 24),
#  (2017, 'GW', 'Forced', 1.1, 23),
#  (2016, 'KORL', 'Opportunistic Maintenance (Planned)', 0.39, 23),
#  (2016, 'GW', 'Forced', 0.85, 22),
#  (2016, 'AURICON', 'Forced', 1.72, 22),
#  (2016, 'MELK', 'Forced', 1.03, 21),
#  (2016, 'AUXC', 'Forced', 0.0, 21),
#  (2017, 'PUG', 'Forced', 0.08, 21),
#  (2017, 'GW', 'Forced', 2.85, 21),
#  (2016, 'TRMOS', 'Forced', 0.07, 20),
#  (2017, 'TRMOS', 'Forced', 1.59, 20),
#  (2017, 'TRMOS', 'Forced', 0.05, 20),
#  (2017, 'PUG', 'Forced', 0.91, 20),
#  (2017, 'AURICON', 'Forced', 0.08, 20),
#  (2016, 'PJRH', 'Forced', 2.89, 19),
#  (2016, 'GW', 'Forced', 0.11, 19),
#  (2016, 'AUXC', 'Forced', 0.0, 19),
#  (2017, 'PUG', 'Forced', 0.52, 19),
#  (2017, 'KORL', 'Forced', 0.77, 19),
#  (2017, 'AUXC', 'Forced', 0.0, 19),
#  (2017, 'GW', 'Consequential', 0.52, 18),
#  (2016, 'PJRH', 'Forced', 0.37, 18),
#  (2016, 'AURICON', 'Forced', 0.44, 18),
#  (2017, 'PJRH', 'Opportunistic Maintenance (Planned)', 0.44, 18),
#  (2016, 'PJRH', 'Forced', 0.21, 17),
#  (2016, 'AUXC', 'Forced', 0.0, 17),
#  (2017, 'MELK', 'Forced', 2.63, 17),
#  (2017, 'PJRH', 'Opportunistic Maintenance (Planned)', 1.52, 17),
#  (2017, 'GW', 'Consequential', 4.86, 16),
#  (2016, 'MELK', 'Forced', 1.13, 16),
#  (2017, 'TRMOS', 'Forced', 0.06, 16),
#  (2017, 'MELK', 'Forced', 2.14, 16),
#  (2017, 'GW', 'Forced', 0.4, 16),
#  (2016, 'MELK', 'Opportunistic Maintenance (Planned)', 3.1, 16),
#  (2016, 'PMC', 'Forced', 0.04, 15),
#  (2016, 'PJRH', 'Forced', 3.25, 15),
#  (2016, 'AURICON', 'Forced', 1.19, 15),
#  (2017, 'TRMOS', 'Forced', 2.09, 15),
#  (2017, 'PMC', 'Forced', 0.06, 15),
#  (2017, 'MELK', 'Forced', 3.31, 15),
#  (2017, 'MELK', 'Forced', 3.74, 15),
#  (2017, 'GW', 'Forced', 1.51, 15),
#  (2017, 'GW', 'Forced', 4.21, 15),
#  (2017, 'PJRH', 'Opportunistic Maintenance (Planned)', 0.29, 15),
#  (2016, 'COLLGAR', 'Consequential', 2.13, 14),
#  (2017, 'AURICON', 'Consequential', 0.53, 14),
#  (2017, 'PJRH', 'Forced', 1.07, 14),
#  (2017, 'GW', 'Forced', 0.43, 14),
#  (2017, 'COLLGAR', 'Forced', 5.44, 14),
#  (2017, 'AUXC', 'Forced', 0.03, 14),
#  (2017, 'KORL', 'Opportunistic Maintenance (Planned)', 0.08, 14),
#  (2016, 'TRMOS', 'Forced', 0.2, 13),
#  (2016, 'AUXC', 'Forced', 0.0, 13),
#  (2017, 'TRMOS', 'Forced', 0.06, 13),
#  (2017, 'PUG', 'Forced', 0.01, 13),
#  (2017, 'AUXC', 'Forced', 0.02, 13),
#  (2017, 'PJRH', 'Opportunistic Maintenance (Planned)', 2.36, 13),
#  (2017, 'KORL', 'Opportunistic Maintenance (Planned)', 0.04, 13),
#  (2016, 'ENRG', 'Scheduled (Planned)', 3.23, 13),
#  (2016, 'AUXC', 'Forced', 0.0, 12),
#  (2016, 'AURICON', 'Forced', 0.21, 12),
#  (2017, 'MELK', 'Forced', 3.85, 12),
#  (2017, 'KORL', 'Forced', 2.69, 12),
#  (2016, 'COLLGAR', 'Scheduled (Planned)', 0.22, 12),
#  (2017, 'KORL', 'Consequential', 0.34, 11),
#  (2016, 'MUND', 'Forced', 0.12, 11),
#  (2016, 'MELK', 'Forced', 5.45, 11),
#  (2016, 'GW', 'Forced', 1.02, 11),
#  (2016, 'AUXC', 'Forced', 0.97, 11),
#  (2016, 'AURICON', 'Forced', 0.34, 11),
#  (2017, 'PUG', 'Forced', 0.02, 11),
#  (2017, 'PJRH', 'Forced', 0.33, 11),
#  (2017, 'GW', 'Forced', 1.21, 11),
#  (2017, 'AUXC', 'Forced', 0.0, 11),
#  (2016, 'TSLA_MGT', 'Consequential', 0.4, 10),
#  (2017, 'PMC', 'Consequential', 0.05, 10),
#  (2017, 'PMC', 'Consequential', 0.21, 10),
#  (2016, 'MELK', 'Forced', 3.87, 10),
#  (2016, 'GW', 'Forced', 0.14, 10),
#  (2016, 'AURICON', 'Forced', 0.42, 10),
#  (2017, 'PUG', 'Forced', 0.1, 10),
#  (2017, 'MUND', 'Forced', 0.28, 10),
#  (2017, 'KORL', 'Forced', 3.94, 10),
#  (2016, 'PUG', 'Opportunistic Maintenance (Planned)', 1.61, 10),
#  (2017, 'PUG', 'Opportunistic Maintenance (Planned)', 0.49, 10),
#  (2017, 'TSLA_MGT', 'Scheduled (Planned)', 1.72, 10),
#  (2016, 'ENRG', 'Consequential', 1.28, 9),
#  (2016, 'TSLA_MGT', 'Forced', 0.62, 9),
#  (2016, 'KORL', 'Forced', 1.13, 9),
#  (2016, 'KORL', 'Forced', 0.41, 9),
#  (2017, 'TRMOS', 'Forced', 0.12, 9),
#  (2017, 'PJRH', 'Forced', 3.62, 9),
#  (2017, 'AUXC', 'Forced', 0.0, 9),
#  (2016, 'KORL', 'Opportunistic Maintenance (Planned)', 0.35, 9),
#  (2016, 'EUCT', 'Consequential', 0.45, 8),
#  (2017, 'TSLA_MGT', 'Consequential', 0.4, 8),
#  (2016, 'TRMOS', 'Forced', 0.18, 8),
#  (2016, 'PUG', 'Forced', 0.8, 8),
#  (2016, 'PMC', 'Forced', 0.63, 8),
#  (2016, 'PJRH', 'Forced', 3.66, 8),
#  (2016, 'GW', 'Forced', 2.29, 8),
#  (2016, 'EUCT', 'Forced', 1.03, 8),
#  (2016, 'AUXC', 'Forced', 0.0, 8),
#  (2016, 'AURICON', 'Forced', 0.08, 8),
#  (2017, 'TSLA_MGT', 'Forced', 0.41, 8),
#  (2017, 'TRMOS', 'Forced', 0.02, 8),
#  (2017, 'PMC', 'Forced', 0.29, 8),
#  (2017, 'PJRH', 'Forced', 0.62, 8),
#  (2017, 'KORL', 'Forced', 4.39, 8),
#  (2017, 'COLLGAR', 'Forced', 3.58, 8),
#  (2017, 'AUXC', 'Forced', 0.0, 8),
#  (2016, 'PJRH', 'Opportunistic Maintenance (Planned)', 0.28, 8),
#  (2016, 'KORL', 'Opportunistic Maintenance (Planned)', 0.38, 8),
#  (2016, 'ENRG', 'Scheduled (Planned)', 1.66, 8),
#  (2017, 'COLLGAR', 'Scheduled (Planned)', 0.19, 8),
#  (2016, 'TSLA_MGT', 'Consequential', 0.25, 7),
#  (2017, 'TSLA_MGT', 'Consequential', 0.27, 7),
#  (2017, 'ENRG', 'Consequential', 4.22, 7),
#  (2016, 'TRMOS', 'Forced', 0.36, 7),
#  (2016, 'TRMOS', 'Forced', 0.27, 7),
#  (2016, 'PMC', 'Forced', 0.07, 7),
#  (2016, 'PMC', 'Forced', 3.1, 7),
#  (2016, 'PJRH', 'Forced', 0.21, 7),
#  (2016, 'PJRH', 'Forced', 0.42, 7),
#  (2016, 'COLLGAR', 'Forced', 0.53, 7),
#  (2016, 'AUXC', 'Forced', 0.0, 7),
#  (2016, 'AUXC', 'Forced', 0.0, 7),
#  (2017, 'PJRH', 'Forced', 3.53, 7),
#  (2017, 'MCG', 'Forced', 0.43, 7),
#  (2017, 'COLLGAR', 'Forced', 0.73, 7),
#  (2017, 'COLLGAR', 'Forced', 0.2, 7),
#  (2017, 'AUXC', 'Forced', 0.14, 7),
#  (2017, 'MUND', 'Opportunistic Maintenance (Planned)', 0.28, 7),
#  (2017, 'ENRG', 'Scheduled (Planned)', 2.76, 7),
#  (2017, 'TSLA_MGT', 'Consequential', 0.44, 6),
#  (2017, 'TSLA_MGT', 'Consequential', 0.2, 6),
#  (2017, 'EUCT', 'Consequential', 0.17, 6),
#  (2017, 'DNHR', 'Consequential', 0.3, 6),
#  (2016, 'STHRNCRS', 'Forced', 0.49, 6),
#  (2016, 'STHRNCRS', 'Forced', 0.31, 6),
#  (2016, 'PUG', 'Forced', 3.08, 6),
#  (2016, 'PMC', 'Forced', 0.01, 6),
#  (2016, 'PJRH', 'Forced', 0.27, 6),
#  (2016, 'PJRH', 'Forced', 1.73, 6),
#  (2016, 'ENRG', 'Forced', 2.8, 6),
#  (2016, 'COLLGAR', 'Forced', 0.37, 6),
#  (2017, 'STHRNCRS', 'Forced', 0.4, 6),
#  (2017, 'PMC', 'Forced', 0.62, 6),
#  (2017, 'KORL', 'Forced', 0.28, 6),
#  (2017, 'KORL', 'Forced', 4.56, 6),
#  (2017, 'ENRG', 'Forced', 1.37, 6),
#  (2017, 'COLLGAR', 'Forced', 0.17, 6),
#  (2016, 'TSLA_MGT', 'Scheduled (Planned)', 0.65, 6),
#  (2016, 'MELK', 'Scheduled (Planned)', 0.61, 6),
#  (2016, 'KORL', 'Scheduled (Planned)', 5.1, 6),
#  (2017, 'MELK', 'Scheduled (Planned)', 2.38, 6),
#  (2017, 'ENRG', 'Scheduled (Planned)', 4.52, 6),
#  (2016, 'TSLA_MGT', 'Consequential', 0.4, 5),
#  (2016, 'PMC', 'Consequential', 1.42, 5),
#  (2016, 'ENRG', 'Consequential', 1.09, 5),
#  (2016, 'ENRG', 'Consequential', 0.28, 5),
#  (2016, 'ENRG', 'Consequential', 9.54, 5),
#  (2017, 'PMC', 'Consequential', 5.46, 5),
#  (2016, 'PMC', 'Forced', 0.12, 5),
#  (2016, 'KORL', 'Forced', 0.5, 5),
#  (2016, 'KORL', 'Forced', 0.31, 5),
#  (2016, 'EUCT', 'Forced', 2.99, 5),
#  (2016, 'ENRG', 'Forced', 1.29, 5),
#  (2017, 'WGUTD', 'Forced', 0.12, 5),
#  (2017, 'TRMOS', 'Forced', 0.07, 5),
#  (2017, 'STHRNCRS', 'Forced', 0.4, 5),
#  (2017, 'STHRNCRS', 'Forced', 0.42, 5),
#  (2017, 'PJRH', 'Forced', 0.25, 5),
#  (2017, 'AUXC', 'Forced', 0.06, 5),
#  (2017, 'PJRH', 'Opportunistic Maintenance (Planned)', 0.29, 5),
#  (2017, 'ENRG', 'Opportunistic Maintenance (Planned)', 1.27, 5),
#  (2016, 'TSLA_MGT', 'Scheduled (Planned)', 6.5, 5),
#  (2016, 'PUG', 'Scheduled (Planned)', 0.27, 5),
#  (2016, 'MUND', 'Scheduled (Planned)', 6.38, 5),
#  (2016, 'ENRG', 'Scheduled (Planned)', 3.44, 5),
#  (2017, 'ENRG', 'Scheduled (Planned)', 0.93, 5),
#  (2017, 'ENRG', 'Scheduled (Planned)', 2.13, 5),
#  (2016, 'TSLA_MGT', 'Consequential', 0.21, 4),
#  (2016, 'STHRNCRS', 'Consequential', 0.27, 4),
#  (2016, 'PMC', 'Consequential', 0.38, 4),
#  (2016, 'EUCT', 'Consequential', 0.23, 4),
#  (2016, 'ENRG', 'Consequential', 6.96, 4),
#  (2017, 'TSLA_MGT', 'Consequential', 0.69, 4),
#  (2016, 'TRMOS', 'Forced', 1.73, 4),
#  (2016, 'STHRNCRS', 'Forced', 0.57, 4),
#  (2016, 'STHRNCRS', 'Forced', 0.52, 4),
#  (2016, 'PUG', 'Forced', 0.29, 4),
#  (2016, 'PUG', 'Forced', 0.35, 4),
#  (2016, 'PMC', 'Forced', 0.17, 4),
#  (2016, 'COLLGAR', 'Forced', 0.08, 4),
#  (2016, 'COLLGAR', 'Forced', 6.61, 4),
#  (2017, 'TRMOS', 'Forced', 0.39, 4),
#  (2017, 'STHRNCRS', 'Forced', 0.37, 4),
#  (2017, 'STHRNCRS', 'Forced', 0.62, 4),
#  (2017, 'PUG', 'Forced', 0.14, 4),
#  (2017, 'PUG', 'Forced', 5.02, 4),
#  (2017, 'MCG', 'Forced', 0.06, 4),
#  (2017, 'GW', 'Forced', 0.31, 4),
#  (2017, 'EUCT', 'Forced', 0.15, 4),
#  (2017, 'ENRG', 'Forced', 4.58, 4),
#  (2017, 'COLLGAR', 'Forced', 0.01, 4),
#  (2016, 'MUND', 'Opportunistic Maintenance (Planned)', 0.13, 4),
#  (2016, 'KORL', 'Opportunistic Maintenance (Planned)', 9.45, 4),
#  (2016, 'PMC', 'Scheduled (Planned)', 9.61, 4),
#  (2017, 'PMC', 'Scheduled (Planned)', 3.38, 4),
#  (2017, 'MUND', 'Scheduled (Planned)', 2.74, 4),
#  (2017, 'MCG', 'Scheduled (Planned)', 0.06, 4),
#  (2017, 'KORL', 'Scheduled (Planned)', 0.11, 4),
#  (2017, 'KORL', 'Scheduled (Planned)', 1.29, 4),
#  (2017, 'ENRG', 'Scheduled (Planned)', 9.4, 4),
#  (2016, 'WGUTD', 'Consequential', 0.65, 3),
#  (2016, 'WGUTD', 'Consequential', 0.02, 3),
#  (2016, 'TSLA_MGT', 'Consequential', 1.35, 3),
#  (2016, 'TSLA_MGT', 'Consequential', 0.96, 3),
#  (2016, 'PMC', 'Consequential', 0.33, 3),
#  (2016, 'DNHR', 'Consequential', 0.12, 3),
#  (2017, 'TSLA_MGT', 'Consequential', 1.18, 3),
#  (2017, 'EUCT', 'Consequential', 0.12, 3),
#  (2016, 'TRMOS', 'Forced', 0.32, 3),
#  (2016, 'TRMOS', 'Forced', 0.31, 3),
#  (2016, 'TRMOS', 'Forced', 0.17, 3),
#  (2016, 'STHRNCRS', 'Forced', 0.38, 3),
#  (2016, 'KORL', 'Forced', 2.01, 3),
#  (2016, 'KORL', 'Forced', 0.22, 3),
#  (2016, 'COLLGAR', 'Forced', 0.02, 3),
#  (2017, 'WGUTD', 'Forced', 8.98, 3),
#  (2017, 'TRMOS', 'Forced', 0.26, 3),
#  (2017, 'STHRNCRS', 'Forced', 0.71, 3),
#  (2017, 'STHRNCRS', 'Forced', 0.15, 3),
#  (2017, 'MUND', 'Forced', 0.01, 3),
#  (2017, 'MUND', 'Forced', 0.02, 3),
#  (2017, 'COLLGAR', 'Forced', 0.68, 3),
#  (2017, 'COLLGAR', 'Forced', 0.63, 3),
#  (2017, 'AUXC', 'Forced', 0.99, 3),
#  (2016, 'MUND', 'Opportunistic Maintenance (Planned)', 0.28, 3),
#  (2016, 'MUND', 'Opportunistic Maintenance (Planned)', 7.22, 3),
#  (2016, 'PUG', 'Scheduled (Planned)', 0.24, 3),
#  (2016, 'PUG', 'Scheduled (Planned)', 0.16, 3),
#  (2016, 'KORL', 'Scheduled (Planned)', 18.03, 3),
#  (2017, 'ENRG', 'Scheduled (Planned)', 8.2, 3),
#  (2016, 'STHRNCRS', 'Consequential', 0.42, 2),
#  (2016, 'STHRNCRS', 'Consequential', 0.53, 2),
#  (2016, 'MCG', 'Consequential', 0.26, 2),
#  (2016, 'DNHR', 'Consequential', 0.73, 2),
#  (2016, 'DNHR', 'Consequential', 0.18, 2),
#  (2017, 'MCG', 'Consequential', 0.23, 2),
#  (2017, 'EUCT', 'Consequential', 1.31, 2),
#  (2017, 'EUCT', 'Consequential', 0.02, 2),
#  (2017, 'DNHR', 'Consequential', 0.26, 2),
#  (2016, 'TRMOS', 'Forced', 0.27, 2),
#  (2016, 'STHRNCRS', 'Forced', 0.38, 2),
#  (2017, 'PUG', 'Forced', 0.54, 2),
#  (2017, 'PUG', 'Forced', 0.18, 2),
#  (2017, 'PMC', 'Forced', 0.0, 2),
#  (2017, 'AUXC', 'Forced', 0.0, 2),
#  (2016, 'WGUTD', 'Opportunistic Maintenance (Planned)', 5.18, 2),
#  (2016, 'PUG', 'Opportunistic Maintenance (Planned)', 0.1, 2),
#  (2017, 'WGUTD', 'Opportunistic Maintenance (Planned)', 5.34, 2),
#  (2017, 'MUND', 'Opportunistic Maintenance (Planned)', 0.06, 2),
#  (2017, 'COLLGAR', 'Opportunistic Maintenance (Planned)', 2.07, 2),
#  (2016, 'PUG', 'Scheduled (Planned)', 0.48, 2),
#  (2016, 'ENRG', 'Scheduled (Planned)', 1.72, 2),
#  (2016, 'ENRG', 'Scheduled (Planned)', 2.48, 2),
#  (2017, 'TSLA_MGT', 'Scheduled (Planned)', 0.28, 2),
#  (2017, 'ENRG', 'Scheduled (Planned)', 1.02, 2),
#  (2016, 'WGUTD', 'Consequential', 0.23, 1),
#  (2016, 'TSLA_MGT', 'Consequential', 0.02, 1),
#  (2016, 'TSLA_MGT', 'Consequential', 0.02, 1),
#  (2016, 'STHRNCRS', 'Consequential', 0.04, 1),
#  (2016, 'DNHR', 'Consequential', 0.44, 1),
#  (2016, 'DNHR', 'Consequential', 0.08, 1),
#  (2016, 'DNHR', 'Consequential', 0.35, 1),
#  (2016, 'DNHR', 'Consequential', 0.06, 1),
#  (2017, 'WGUTD', 'Consequential', 0.04, 1),
#  (2017, 'TSLA_MGT', 'Consequential', 0.31, 1),
#  (2017, 'DNHR', 'Consequential', 0.13, 1),
#  (2017, 'DNHR', 'Consequential', 0.33, 1),
#  (2017, 'DNHR', 'Consequential', 0.33, 1),
#  (2017, 'DNHR', 'Consequential', 0.13, 1),
#  (2017, 'DNHR', 'Consequential', 0.17, 1),
#  (2016, 'TRMOS', 'Forced', 0.17, 1),
#  (2016, 'PJRH', 'Forced', 0.31, 1),
#  (2016, 'MUND', 'Forced', 0.73, 1),
#  (2016, 'MUND', 'Forced', 0.06, 1),
#  (2016, 'MCG', 'Forced', 0.79, 1),
#  (2016, 'EUCT', 'Forced', 9.81, 1),
#  (2016, 'EUCT', 'Forced', 19.29, 1),
#  (2016, 'EUCT', 'Forced', 15.02, 1),
#  (2016, 'DNHR', 'Forced', 0.4, 1),
#  (2016, 'COLLGAR', 'Forced', 0.06, 1),
#  (2017, 'STHRNCRS', 'Forced', 0.02, 1),
#  (2017, 'STHRNCRS', 'Forced', 0.65, 1),
#  (2017, 'STHRNCRS', 'Forced', 0.33, 1),
#  (2017, 'STHRNCRS', 'Forced', 0.33, 1),
#  (2017, 'STHRNCRS', 'Forced', 0.31, 1),
#  (2017, 'MCG', 'Forced', 0.17, 1),
#  (2017, 'KORL', 'Forced', 0.17, 1),
#  (2017, 'COLLGAR', 'Forced', 0.0, 1),
#  (2016, 'MUND', 'Opportunistic Maintenance (Planned)', 0.21, 1),
#  (2017, 'WGUTD', 'Opportunistic Maintenance (Planned)', 0.0, 1),
#  (2017, 'MUND', 'Opportunistic Maintenance (Planned)', 0.63, 1),
#  (2017, 'MUND', 'Opportunistic Maintenance (Planned)', 0.08, 1),
#  (2017, 'COLLGAR', 'Opportunistic Maintenance (Planned)', 0.25, 1),
#  (2016, 'TSLA_MGT', 'Scheduled (Planned)', 1.42, 1),
#  (2016, 'STHRNCRS', 'Scheduled (Planned)', 0.23, 1),
#  (2016, 'MUND', 'Scheduled (Planned)', 8.92, 1),
#  (2016, 'MCG', 'Scheduled (Planned)', 1.42, 1),
#  (2016, 'COLLGAR', 'Scheduled (Planned)', 1.56, 1),
#  (2016, 'COLLGAR', 'Scheduled (Planned)', 24.04, 1),
#  (2017, 'PMC', 'Scheduled (Planned)', 0.1, 1)]

# %% [markdown]
# <h3 style = "color:#5D3FD3"> Expected Output (Sample) </h3>

# %%
# Out:
#  * sqlite:///AEMR.db
# Done.
# [('AURICON', 'Forced', 2017, 490, 0.07),
#  ('GW', 'Forced', 2016, 317, 0.38),
#  ('GW', 'Forced', 2017, 227, 1.06),
#  ('AURICON', 'Forced', 2016, 208, 0.07),
#  ('AUXC', 'Forced', 2016, 206, 0.08)]

# %% [markdown]
# Now we're getting somewhere...!
# We've identified participants who are having many outages, as well as participants who have been offline for the longest durations.
#
# Armed with this information, it's important we're able to classify our participants accordingly based on reliability metrics of uptime.
#
# We classify a participant based off the following criteria:
# <b>
# <li> High Risk - On average, the participant is unavailable for > 24 Hours (1 Day)</li>
# <li> Medium Risk - On average, the participant is unavailable between 12 and 24 Hours </li>
# <li> Low Risk - On average, the participant is unavailable for less than 12 Hours</li>
# </b>

# %% [markdown]
# <h3 style="color:#D4AF37"> Question Four </h3>

# %% [markdown]
# <b> Using the above criteria for context, write a SQL Statement that <u> classifies each participant code as either `High Risk`, `Medium Risk` or `Low Risk` in a column called `Risk_Classification`</u> that is based off their Average Outage Duration Time. Please note that this is for all valid (i.e. `Where status = approved`) outage types (Forced, Consequential, Scheduled, Opportunistic) for <u>all</u> participant codes from 2016 to 2017. Order the results using `Average Duration Time In Days` in descending order.
#
# <b>⚠️Hint: Think about the CASE Statement and how you might use this to help you with your classification! This is a more challenging question so you'll need to think through this step by step. You might also find `CTEs` or `Sub Queries` helpful for you.</b>

# %% [markdown]
# <h4 style="color:Teal"> Please write your SQL in the code window below </h4>

# %%
# %%sql
# --Question Four Response
# WITH table_1 AS (
# SELECT
# year,
# participant_code,
# outage_reason,
# ROUND(AVG(ABS(JULIANDAY(end_time) - JULIANDAY(start_time))), 2) AS avg_duration_days,
# COUNT(status) AS total_number_outage_events
# FROM AEMR_Outage_Table
# WHERE status = 'Approved'
#     AND (year = 2016
#     OR year = 2017)
# GROUP BY participant_code, year, month
# ORDER BY total_number_outage_events DESC, outage_reason, year)
#
# SELECT
#     year,
#     participant_code,
#     avg_duration_days,
#     total_number_outage_events,
#     outage_reason,
#     CASE
#         WHEN avg_duration_days < .5 THEN 'Low Risk'
#         WHEN avg_duration_days > 1 THEN 'High Risk'
#         ELSE 'Medium Risk'
#     END AS risk_classification
# FROM table_1
# GROUP BY participant_code, year
# ORDER BY avg_duration_days DESC;
# Out:
#  * sqlite:///temp_db_file.db
# Done.
# [(2017, 'COLLGAR', 5.44, 14, 'Forced', 'High Risk'),
#  (2017, 'ENRG', 4.22, 7, 'Consequential', 'High Risk'),
#  (2016, 'ENRG', 3.23, 13, 'Scheduled (Planned)', 'High Risk'),
#  (2016, 'COLLGAR', 2.13, 14, 'Consequential', 'High Risk'),
#  (2017, 'MELK', 1.94, 41, 'Forced', 'High Risk'),
#  (2017, 'TSLA_MGT', 1.72, 10, 'Scheduled (Planned)', 'High Risk'),
#  (2016, 'PUG', 1.61, 10, 'Opportunistic Maintenance (Planned)', 'High Risk'),
#  (2016, 'PJRH', 1.02, 30, 'Opportunistic Maintenance (Planned)', 'High Risk'),
#  (2016, 'MELK', 0.92, 42, 'Forced', 'Medium Risk'),
#  (2017, 'KORL', 0.77, 19, 'Forced', 'Medium Risk'),
#  (2016, 'WGUTD', 0.65, 3, 'Consequential', 'Medium Risk'),
#  (2016, 'GW', 0.61, 110, 'Forced', 'Medium Risk'),
#  (2016, 'STHRNCRS', 0.49, 6, 'Forced', 'Low Risk'),
#  (2016, 'EUCT', 0.45, 8, 'Consequential', 'Low Risk'),
#  (2017, 'MCG', 0.43, 7, 'Forced', 'Low Risk'),
#  (2017, 'GW', 0.41, 67, 'Forced', 'Low Risk'),
#  (2017, 'STHRNCRS', 0.4, 6, 'Forced', 'Low Risk'),
#  (2016, 'TSLA_MGT', 0.4, 10, 'Consequential', 'Low Risk'),
#  (2016, 'KORL', 0.39, 23, 'Opportunistic Maintenance (Planned)', 'Low Risk'),
#  (2017, 'PJRH', 0.36, 24, 'Opportunistic Maintenance (Planned)', 'Low Risk'),
#  (2017, 'DNHR', 0.3, 6, 'Consequential', 'Low Risk'),
#  (2016, 'PMC', 0.29, 39, 'Scheduled (Planned)', 'Low Risk'),
#  (2017, 'MUND', 0.28, 10, 'Forced', 'Low Risk'),
#  (2016, 'MCG', 0.26, 2, 'Consequential', 'Low Risk'),
#  (2016, 'AURICON', 0.19, 63, 'Forced', 'Low Risk'),
#  (2017, 'EUCT', 0.17, 6, 'Consequential', 'Low Risk'),
#  (2017, 'AURICON', 0.14, 125, 'Forced', 'Low Risk'),
#  (2016, 'DNHR', 0.12, 3, 'Consequential', 'Low Risk'),
#  (2016, 'MUND', 0.12, 11, 'Forced', 'Low Risk'),
#  (2017, 'WGUTD', 0.12, 5, 'Forced', 'Low Risk'),
#  (2016, 'TRMOS', 0.07, 20, 'Forced', 'Low Risk'),
#  (2017, 'TRMOS', 0.07, 32, 'Forced', 'Low Risk'),
#  (2017, 'PMC', 0.06, 15, 'Forced', 'Low Risk'),
#  (2017, 'PUG', 0.02, 33, 'Forced', 'Low Risk'),
#  (2016, 'AUXC', 0.0, 38, 'Forced', 'Low Risk'),
#  (2017, 'AUXC', 0.0, 31, 'Forced', 'Low Risk')]

# %% [markdown]
# <h3 style = "color:#5D3FD3"> Expected Output (Sample) </h3>

# %%
# Out:
#  * sqlite:///AEMR.db
# Done.
# [('AURICON', 'Forced', 2017, 490, 0.07, 'Low Risk'),
#  ('GW', 'Forced', 2016, 317, 0.38, 'Low Risk'),
#  ('GW', 'Forced', 2017, 227, 1.06, 'High Risk')]

# %% [markdown]
# Now that we've classified our participants as either `High Risk`, `Medium Risk` or `Low Risk`, we want to dig a little deeper.
#
# Does it make sense that `Consequential`, `Opportunistic` or `Planned` aren't considered regarding the Risk Category?
#
# Perhaps we should refine our category accordingly by ensuring we focus our Risk Category on labelling only `Forced` Outages as being a Risk. After all, Forced Outages are the unplanned outages that risk the security of the electricity grid.
#
# Let's add two additional criteria to our classification considering `Total Number of Outage Events` and `Outage Type`.
#
# We've summarised these below:
#
# <b>
# <li> High Risk - On average, the participant is unavailable for > 24 Hours (1 Day) OR the Total Number of Outage Events > 20 </li>
# <li> Medium Risk - On average, the participant is unavailable between 12 and 24 Hours OR the Total Number of Outage Events is Between 10 and 20 </li>
# <li> Low Risk - On average, the participant is unavailable for less than 12 Hours OR the Total Number of Outage Events < 10 </li>
# <li> If Outage Type is not forced, then N/A
# </b>

# %% [markdown]
# <h3 style="color:#D4AF37"> Question Five </h3>

# %% [markdown]
# <b> Just as you did in Question Four, Using the above criteria for context, write a SQL Statement that <u> classifies each participant code as either `High Risk`, `Medium Risk` or `Low Risk` in a column called `Risk_Classification`</u> using the new classification criteria. Order the results using `Average Duration Time In Days` in descending order.
#
# <b>⚠️Hint: Think about the CASE Statement and how you might use this to help you with your classification! </b>

# %% [markdown]
# <h4 style="color:Teal"> Please write your SQL in the code window below </h4>

# %%
# %%sql
# --Question Five Response
# WITH table_1 AS (
# SELECT
# year,
# participant_code,
# outage_reason,
# ROUND(AVG(ABS(JULIANDAY(end_time) - JULIANDAY(start_time))), 2) AS avg_duration_days,
# COUNT(status) AS total_number_outage_events
# FROM AEMR_Outage_Table
# WHERE status = 'Approved'
#     AND (year = 2016
#     OR year = 2017)
# GROUP BY participant_code, year, month
# ORDER BY total_number_outage_events DESC, outage_reason, year)
#
# SELECT
#     year,
#     participant_code,
#     outage_reason,
#     CASE
#         WHEN avg_duration_days < .5 OR total_number_outage_events < 10 THEN 'Low Risk'
#         WHEN avg_duration_days > 1 OR total_number_outage_events > 20 THEN 'High Risk'
#         ELSE 'Medium Risk'
#     END AS risk_classification
# FROM table_1
# WHERE outage_reason IS NOT 'Forced'
# GROUP BY participant_code, year
# ORDER BY avg_duration_days DESC;
# Out:
#  * sqlite:///temp_db_file.db
# Done.
# [(2016, 'MUND', 'Scheduled (Planned)', 'Low Risk'),
#  (2017, 'WGUTD', 'Opportunistic Maintenance (Planned)', 'Low Risk'),
#  (2017, 'ENRG', 'Consequential', 'Low Risk'),
#  (2016, 'ENRG', 'Scheduled (Planned)', 'High Risk'),
#  (2016, 'MELK', 'Opportunistic Maintenance (Planned)', 'High Risk'),
#  (2016, 'GW', 'Consequential', 'High Risk'),
#  (2017, 'MELK', 'Scheduled (Planned)', 'Low Risk'),
#  (2016, 'COLLGAR', 'Consequential', 'High Risk'),
#  (2017, 'TSLA_MGT', 'Scheduled (Planned)', 'High Risk'),
#  (2016, 'PUG', 'Opportunistic Maintenance (Planned)', 'High Risk'),
#  (2016, 'PJRH', 'Opportunistic Maintenance (Planned)', 'High Risk'),
#  (2016, 'WGUTD', 'Consequential', 'Low Risk'),
#  (2017, 'AURICON', 'Consequential', 'Medium Risk'),
#  (2017, 'GW', 'Consequential', 'Medium Risk'),
#  (2017, 'PUG', 'Opportunistic Maintenance (Planned)', 'Low Risk'),
#  (2016, 'EUCT', 'Consequential', 'Low Risk'),
#  (2016, 'TSLA_MGT', 'Consequential', 'Low Risk'),
#  (2016, 'KORL', 'Opportunistic Maintenance (Planned)', 'Low Risk'),
#  (2017, 'PJRH', 'Opportunistic Maintenance (Planned)', 'Low Risk'),
#  (2017, 'DNHR', 'Consequential', 'Low Risk'),
#  (2016, 'PMC', 'Scheduled (Planned)', 'Low Risk'),
#  (2017, 'MUND', 'Opportunistic Maintenance (Planned)', 'Low Risk'),
#  (2016, 'STHRNCRS', 'Consequential', 'Low Risk'),
#  (2016, 'MCG', 'Consequential', 'Low Risk'),
#  (2016, 'AUXC', 'Consequential', 'Low Risk'),
#  (2017, 'COLLGAR', 'Scheduled (Planned)', 'Low Risk'),
#  (2017, 'EUCT', 'Consequential', 'Low Risk'),
#  (2016, 'DNHR', 'Consequential', 'Low Risk'),
#  (2017, 'KORL', 'Opportunistic Maintenance (Planned)', 'Low Risk'),
#  (2017, 'MCG', 'Scheduled (Planned)', 'Low Risk'),
#  (2017, 'PMC', 'Consequential', 'Low Risk')]

# %% [markdown]
# <h3 style = "color:#5D3FD3"> Expected Output (Sample) </h3>

# %%
# Out:
#  * sqlite:///AEMR.db
# Done.
# [('AURICON', 'Scheduled (Planned)', 2016, 46, 1.89, 'N/A'),
#  ('AURICON', 'Scheduled (Planned)', 2017, 45, 1.45, 'N/A'),
#  ('AURICON', 'Opportunistic Maintenance (Planned)', 2016, 3, 0.33, 'N/A')]

# %% [markdown]
# <h3 style="color:#D4AF37"> ⚡ Part II. Energy Losses & Market Reliability ⚡ </h3>

# %% [markdown]
# When an energy provider provides energy to the market, they are making a commitment to the market and saying; “We will supply X amount of energy to the market under a contractual obligation.” However, in a situation where the outages are Forced, the energy provider intended to provide energy but are unable to provide energy and are forced offline. <b style="color:Maroon">If many energy providers are forced offline at the same time it could cause an energy security risk that AEMR needs to mitigate. </b>
#
# To ensure this doesn’t happen, the AEMR is interested in exploring the following questions:
#
# <li> Of the outage types in 2016 and 2017, what percent were Forced Outage(s)?
# <li> What was the average duration for a forced outage during both 2016 and 2017? Have we seen an increase in the average duration of forced outages?
# <li> Which energy providers tended to have the largest number of forced outages?
#
# <p>
#
# <b> We'll examine this in the questions below. </b>
#
# <img src = "https://media.istockphoto.com/id/1281821795/photo/market-stock-graph-and-information-with-city-light-and-electricity-and-energy-facility-banner.jpg?s=612x612&w=0&k=20&c=RSN5LqeMW28HW10aA190_DWR5YJ5tG2wixHFPBV3uZE=">

# %% [markdown]
# <h3 style="color:#D4AF37"> Question Six </h3>

# %% [markdown]
# <b> Write a SQL Statement to calculate the proportion of Forced Outages that have occurred over the 2016 - 2017 Period.
# Do we observe any particular increases regarding any Outage Types over this period? </b>

# %% [markdown]
# <h4 style="color:Teal"> Please write your SQL in the code window below </h4>

# %%
# %%sql
# --Question Six Response Had a bit of trouble with this one so had to reference the video
# SELECT
# year,
# COUNT (*) AS Valid_Outage_Events,
# SUM (CASE WHEN outage_reason = 'Forced' THEN 1 END) AS Forced_Outages,
# ROUND((SUM(CASE WHEN outage_reason = 'Forced' THEN 1 ELSE 0 END) * 100.0) / COUNT(*),2) AS Percentage_Forced
# FROM AEMR_Outage_Table
# WHERE status = 'Approved'
#     AND year IN (2016, 2017)
# GROUP BY year
# ORDER BY year;
# Out:
#  * sqlite:///temp_db_file.db
# Done.
# [(2016, 1931, 1264, 65.46), (2017, 2171, 1622, 74.71)]

# %% [markdown]
# <h3 style = "color:#5D3FD3"> Expected Output (Sample) </h3>

# %%
# Out:
#  * sqlite:///AEMR.db
# Done.
# [(1931, 1264, 65.46), (2171, 1622, 74.71)]

# %% [markdown]
# Great. It's clear to see now that `Forced Outages` are problematic for us. Not only are they the only outage type that generates financial losses as the Outage is unplanned, it seems there is a number of Energy Participants who have been having a significantly high number of Outages.
#
# Now what can we do about this?
#
# Let's break our analysis down into Macro and Micro Analysis.
# The total gives us the Overall Duration a participant is offline / has lost energy, however, it doesn't tell us how *frequently* this occurs. In other words, if we have one or two very big outages, it might contribute to very large totals.
#
# However, perhaps an <b> average </b> can help us identify how big these Outages might really be, spread across the year!
#
# Let's take a look.

# %% [markdown]
# <h3 style="color:#D4AF37"> Question Seven </h3>

# %% [markdown]
# Write a SQL Statement to calculate the `Total Number of Outages`, `Total Duration In Days`and `Total Energy Lost` of all valid `Outages` for each `participant code` and `facility_code`, sorted by `Total Energy Lost` in descending order and Ordered by the YEAR Category.

# %% [markdown]
# <h4 style="color:Teal"> Please write your SQL in the code window below </h4>

# %%
# %%sql
# --Question Seven Response
# SELECT
# participant_code,
# outage_reason,
# facility_code,
# COUNT (status) AS Total_Number_of_Outages,
# ROUND(SUM(ABS(JULIANDAY(end_time) - JULIANDAY(start_time))), 2) AS Total_Duration_In_Days,
# SUM(Energy_Lost_MW) AS Total_Energy_Lost
# FROM AEMR_Outage_Table
# WHERE status = 'Approved'
#     AND year IN (2016, 2017)
# GROUP BY year, participant_code
# ORDER BY Total_Energy_Lost DESC, year;
# Out:
#  * sqlite:///temp_db_file.db
# Done.
# [('AURICON', 'Forced', 'AURICON_PNJ_U1', 577, 107.92, 30134.037),
#  ('MELK', 'Forced', 'MELK_G7', 273, 544.21, 27841.714),
#  ('GW', 'Forced', 'BW1_GREENWATERS_G2', 402, 329.81, 25985.101),
#  ('GW', 'Forced', 'BW1_GREENWATERS_G2', 270, 314.21, 24651.792),
#  ('AURICON', 'Forced', 'AURICON_PNJ_U1', 298, 108.37, 22109.624),
#  ('MELK', 'Forced', 'MELK_G7', 263, 897.17, 19124.377),
#  ('PMC', 'Forced', 'PMC_AG', 107, 88.35, 14910.085),
#  ('PJRH', 'Forced', 'PJRH_GT11', 142, 192.9, 10505.465),
#  ('PJRH', 'Forced', 'PJRH_GT11', 146, 160.65, 10050.241),
#  ('PMC', 'Consequential', 'PMC_AG', 61, 50.31, 9295.303),
#  ('COLLGAR', 'Forced', 'COLLGAR_WF1', 53, 90.85, 7834.724),
#  ('KORL', 'Forced', 'KORL_GT3', 108, 161.73, 7355.028),
#  ('KORL', 'Opportunistic Maintenance (Planned)', 'KORL_GT3', 87, 162.29, 6897.969999999999),
#  ('COLLGAR', 'Forced', 'COLLGAR_WF1', 64, 122.19, 6109.793),
#  ('PUG', 'Forced', 'PERTHENERGY_KORL_GT1', 149, 58.83, 5620.1),
#  ('TRMOS', 'Forced', 'TIWEST_COG1', 176, 81.13, 5185.07),
#  ('AUXC', 'Forced', 'AUXC_WGP', 209, 19.5, 2809.14),
#  ('PUG', 'Forced', 'PERTHENERGY_KORL_GT1', 47, 47.21, 2729.472),
#  ('ENRG', 'Scheduled (Planned)', 'ENRG_KALGOORLIE_GT3', 69, 198.02, 1876.8),
#  ('AUXC', 'Forced', 'AUXC_WGP', 122, 5.08, 1820.76),
#  ('TRMOS', 'Forced', 'TIWEST_COG1', 71, 19.77, 1400.83),
#  ('TSLA_MGT', 'Consequential', 'TESLA_PICTON_G1', 55, 36.71, 1076.0),
#  ('MUND', 'Forced', 'MUNDARING_GT1', 30, 66.15, 1059.2),
#  ('MUND', 'Opportunistic Maintenance (Planned)', 'MUNDARING_GT1', 31, 16.65, 996.897),
#  ('TSLA_MGT', 'Forced', 'TESLA_PICTON_G1', 55, 58.96, 905.8000000000001),
#  ('MCG', 'Scheduled (Planned)', 'MWF_MUMBIDA_WF1', 18, 4.08, 877.333),
#  ('STHRNCRS', 'Forced', 'STHRNCRS_EG', 35, 14.27, 805.0),
#  ('ENRG', 'Forced', 'ENRG_KALGOORLIE_GT3', 54, 188.35, 796.676),
#  ('STHRNCRS', 'Forced', 'STHRNCRS_EG', 35, 14.69, 683.7),
#  ('WGUTD', 'Forced', 'WEST_KALGOORLIE_GT2', 12, 38.27, 365.294),
#  ('EUCT', 'Forced', 'GRASMERE_WF1', 28, 71.85, 355.20000000000005),
#  ('WGUTD', 'Consequential', 'WEST_KALGOORLIE_GT2', 9, 12.6, 288.0),
#  ('EUCT', 'Consequential', 'GRASMERE_WF1', 17, 4.63, 287.1),
#  ('MCG', 'Forced', 'MWF_MUMBIDA_WF1', 4, 2.73, 220.0),
#  ('DNHR', 'Consequential', 'DNHR_DENMARK_WF1', 13, 3.38, 18.72),
#  ('DNHR', 'Consequential', 'DNHR_DENMARK_WF1', 12, 3.52, 17.28)]

# %% [markdown]
# <h3 style = "color:#5D3FD3"> Expected Output (Sample) </h3>

# %%
# Out:
#  * sqlite:///AEMR.db
# Done.
# [(70, 482.58, 7499.28, 'Scheduled (Planned)', 'MELK', 'MELK_G7', 2017),
#  (177, 404.15, 10285.4, 'Forced', 'MELK', 'MELK_G7', 2017),
#  (85, 392.25, 9668.79, 'Scheduled (Planned)', 'MELK', 'MELK_G7', 2016),
#  (227, 240.69, 19326.56, 'Forced', 'GW', 'BW1_GREENWATERS_G2', 2017),
#  (45, 199.4, 6450.0, 'Scheduled (Planned)', 'GW', 'BW1_GREENWATERS_G2', 2016)]

# %% [markdown]
# <h3 style="color:#D4AF37"> Question Eight </h3>

# %% [markdown]
# <b> Write a SQL Statement to calculate the `Average Duration In Days`and `Average Energy Lost` of all valid `FORCED OUTAGES` for each `participant code` and `facility_code` sorted by `Average Energy Lost` in descending order and Ordered by the YEAR Category.

# %% [markdown]
# <h4 style="color:Teal"> Please write your SQL in the code window below </h4>

# %%
# %%sql
# --Question Eight Response Had a bit of trouble with this one so had to reference the video
# SELECT
# ROUND(AVG(ABS(JULIANDAY(end_time) - JULIANDAY(start_time))), 2) AS Average_Duration_In_Days,
# ROUND(AVG(Energy_Lost_MW),2) AS Average_Energy_Lost,
# outage_reason,
# participant_code,
# facility_code,
# year
# FROM AEMR_Outage_Table
# WHERE status = 'Approved'
#     AND outage_reason = 'Forced'
#     AND year IN (2016, 2017)
# GROUP BY year, participant_code
# ORDER BY Average_Energy_Lost DESC, year;
# Out:
#  * sqlite:///temp_db_file.db
# Done.
# [(1.11, 149.0, 'Forced', 'COLLGAR', 'COLLGAR_WF1', 2016),
#  (0.04, 141.21, 'Forced', 'PMC', 'PMC_AG', 2017),
#  (0.49, 131.78, 'Forced', 'PMC', 'PMC_AG', 2016),
#  (0.83, 87.71, 'Forced', 'MELK', 'MELK_G7', 2016),
#  (1.06, 85.14, 'Forced', 'GW', 'BW1_GREENWATERS_G2', 2017),
#  (0.25, 80.0, 'Forced', 'TSLA_MGT', 'TESLA_PICTON_G1', 2016),
#  (0.38, 76.23, 'Forced', 'KORL', 'KORL_GT3', 2016),
#  (1.22, 72.61, 'Forced', 'PJRH', 'PJRH_GT11', 2016),
#  (0.84, 67.21, 'Forced', 'PJRH', 'PJRH_GT11', 2017),
#  (1.38, 61.93, 'Forced', 'COLLGAR', 'COLLGAR_WF1', 2017),
#  (1.21, 61.57, 'Forced', 'KORL', 'KORL_GT3', 2017),
#  (2.28, 58.11, 'Forced', 'MELK', 'MELK_G7', 2017),
#  (2.24, 56.32, 'Forced', 'ENRG', 'ENRG_KALGOORLIE_GT3', 2016),
#  (0.79, 55.0, 'Forced', 'MCG', 'MWF_MUMBIDA_WF1', 2016),
#  (0.07, 51.42, 'Forced', 'AURICON', 'AURICON_PNJ_U1', 2016),
#  (0.38, 49.69, 'Forced', 'GW', 'BW1_GREENWATERS_G2', 2016),
#  (0.28, 46.94, 'Forced', 'MCG', 'MWF_MUMBIDA_WF1', 2017),
#  (0.07, 44.16, 'Forced', 'AURICON', 'AURICON_PNJ_U1', 2017),
#  (0.31, 42.48, 'Forced', 'TSLA_MGT', 'TESLA_PICTON_G1', 2017),
#  (0.37, 36.8, 'Forced', 'MUND', 'MUNDARING_GT1', 2016),
#  (0.92, 33.98, 'Forced', 'PUG', 'PERTHENERGY_KORL_GT1', 2016),
#  (0.25, 30.46, 'Forced', 'PUG', 'PERTHENERGY_KORL_GT1', 2017),
#  (0.42, 29.17, 'Forced', 'TRMOS', 'TIWEST_COG1', 2017),
#  (3.44, 27.66, 'Forced', 'WGUTD', 'WEST_KALGOORLIE_GT2', 2017),
#  (0.26, 27.41, 'Forced', 'ENRG', 'ENRG_KALGOORLIE_GT3', 2017),
#  (0.02, 27.0, 'Forced', 'WGUTD', 'WEST_KALGOORLIE_GT2', 2016),
#  (0.19, 26.57, 'Forced', 'MUND', 'MUNDARING_GT1', 2017),
#  (0.33, 23.0, 'Forced', 'STHRNCRS', 'STHRNCRS_EG', 2016),
#  (0.03, 21.6, 'Forced', 'EUCT', 'GRASMERE_WF1', 2017),
#  (0.19, 18.96, 'Forced', 'TRMOS', 'TIWEST_COG1', 2016),
#  (0.26, 16.26, 'Forced', 'STHRNCRS', 'STHRNCRS_EG', 2017),
#  (0.02, 14.74, 'Forced', 'AUXC', 'AUXC_WGP', 2017),
#  (0.08, 13.27, 'Forced', 'AUXC', 'AUXC_WGP', 2016),
#  (5.9, 5.89, 'Forced', 'EUCT', 'GRASMERE_WF1', 2016),
#  (0.4, 1.44, 'Forced', 'DNHR', 'DNHR_DENMARK_WF1', 2016),
#  (0.48, 1.44, 'Forced', 'DNHR', 'DNHR_DENMARK_WF1', 2017)]

# %% [markdown]
# <h3 style = "color:#5D3FD3"> Expected Output (Sample) </h3>

# %%
# Out:
#  * sqlite:///AEMR.db
# Done.
# [(5.9, 5.89, 'Forced', 'EUCT', 'GRASMERE_WF1', 2016),
#  (3.44, 27.66, 'Forced', 'WGUTD', 'WEST_KALGOORLIE_GT2', 2017),
#  (2.28, 58.11, 'Forced', 'MELK', 'MELK_G7', 2017)]

# %% [markdown]
# <h3 style="color:#D4AF37"> Question Nine </h3>

# %% [markdown]
# <b> Write a SQL Statement to calculate the `Average Energy Lost` and `Total Energy Lost` for each `Facility Code` and `Participant Code` across both the 2016 and 2017 periods when the `Outage_Reason` is set to Forced. Upon completion of this, calculate the <u> percentage </u> of energy lost due to forced outages for each `Facility_Code`. Please ORDER the query by `Total Energy Lost` from 2016 to 2017.
#
# From your analysis, which participants have contributed the most to the Energy Lost due to Forced Outages?

# %% [markdown]
# <h4 style="color:Teal"> Please write your SQL in the code window below </h4>

# %%
# %%sql
# --Question Nine Response
# SELECT
# ROUND(AVG(Energy_Lost_MW),2) AS Average_Energy_Lost,
# ROUND(SUM(Energy_Lost_MW),2) AS Total_Energy_Lost,
# ROUND(SUM(Energy_Lost_MW),2) / (SELECT(ROUND(SUM(Energy_Lost_MW),2)) FROM AEMR_Outage_Table WHERE status = 'Approved') AS Percent_Energy_Lost,
# participant_code,
# facility_code,
# year
# FROM AEMR_Outage_Table
# WHERE status = 'Approved'
#     AND outage_reason = 'Forced'
# GROUP BY participant_code
# ORDER BY Total_Energy_Lost DESC;
# Out:
#  * sqlite:///temp_db_file.db
# Done.
# [(64.48, 35077.94, 0.13864818695584655, 'GW', 'BW1_GREENWATERS_G2', 2017),
#  (46.33, 32335.83, 0.1278097916585886, 'AURICON', 'AURICON_PNJ_U1', 2017),
#  (72.03, 24056.47, 0.09508500071719472, 'MELK', 'MELK_G7', 2017),
#  (135.24, 14741.52, 0.05826696268290985, 'PMC', 'PMC_AG', 2017),
#  (70.07, 10720.8, 0.04237476552831322, 'PJRH', 'PJRH_GT11', 2017),
#  (67.6, 8720.0, 0.03446645356754079, 'KORL', 'KORL_GT3', 2017),
#  (96.05, 7107.91, 0.028094547015740694, 'COLLGAR', 'COLLGAR_WF1', 2017),
#  (26.37, 6249.1, 0.024700036122582474, 'TRMOS', 'TIWEST_COG1', 2017),
#  (30.99, 4927.57, 0.019476589748372356, 'PUG', 'PERTHENERGY_KORL_GT1', 2017),
#  (13.81, 4502.9, 0.01779804974418342, 'AUXC', 'AUXC_WGP', 2017),
#  (49.09, 1374.66, 0.005433446681325186, 'ENRG', 'ENRG_KALGOORLIE_GT3', 2017),
#  (47.56, 618.33, 0.0024439956690845755, 'MCG', 'MWF_MUMBIDA_WF1', 2017),
#  (19.09, 591.7, 0.0023387385981552622, 'STHRNCRS', 'STHRNCRS_EG', 2017),
#  (28.73, 545.78, 0.002157236356432616, 'MUND', 'MUNDARING_GT1', 2017),
#  (54.98, 329.9, 0.001303954476138957, 'TSLA_MGT', 'TESLA_PICTON_G1', 2017),
#  (27.53, 275.29, 0.0010881043580972826, 'WGUTD', 'WEST_KALGOORLIE_GT2', 2017),
#  (9.26, 129.6, 0.0005122537135726245, 'EUCT', 'GRASMERE_WF1', 2017),
#  (1.44, 2.88, 1.1383415857169434e-05, 'DNHR', 'DNHR_DENMARK_WF1', 2017)]

# %% [markdown]
# <h3 style = "color:#5D3FD3"> Expected Output (Sample) </h3>

# %%
# Out:
#  * sqlite:///AEMR.db
# Done.
# [(44.16, 21639.55, 14.21, 'Forced', 'AURICON', 'AURICON_PNJ_U1', 2017),
#  (85.14, 19326.56, 12.69, 'Forced', 'GW', 'BW1_GREENWATERS_G2', 2017),
#  (49.69, 15751.38, 10.34, 'Forced', 'GW', 'BW1_GREENWATERS_G2', 2016)]

# %% [markdown]
# <h3 style="color:#D4AF37"> Question Ten </h3>

# %% [markdown]
# <b>Having identified the top 3 participants by Total Energy Loss being `GW`, `MELK` and `Auricon`; Write a SQL Statement calculating the `Total_Energy_Lost` each of these three `Participant_Codes` and the `Facility_Code`. Additionally, identify the `Description_Of_Outage` associated with the highest `Total_Energy_Lost` for each of the `Participant_Codes` and `Facility_Code` for each of the three participants.
#
# <u>Lastly, calculate the percentage of Energy Loss, attributed to these reasons!</u> </b>
#
# <b> ⚠️ Hint: As this is the final question, this is a bit of a <b> challenge question </b> which will involve some SQL functions you're not familiar with just yet. In the workplace, you're going to have to grow familiar with googling and searching for functions that you may have not learned or be familiar with. In this question, to identify the TOP `Description_Of_Outage` reason for each Participant, you're going to need to use `PARTITION BY`. You can read all about the approach you can take in this example <a href = "https://learnsql.com/cookbook/how-to-rank-rows-within-a-partition-in-sql/#:~:text=To%20partition%20rows%20and%20rank,rank%20rows%20within%20a%20partition."> here </a>. Good luck!

# %% [markdown]
# <h4 style="color:Teal"> Please write your SQL in the code window below </h4>

# %%
# %%sql
# --Question Ten Response could not figure out how to get Percent_Energy_Lost to Round to two decimal places and mulitply by 100
# WITH table_5 AS (
# SELECT
# participant_code,
# facility_code,
# ROUND(SUM(Energy_Lost_MW),2) AS Total_Energy_Lost,
# ROUND(SUM(Energy_Lost_MW),2) / (SELECT(ROUND(SUM(Energy_Lost_MW),2)) FROM AEMR_Outage_Table WHERE status = 'Approved') AS Percent_Energy_Lost,
# description_of_outage
# FROM AEMR_Outage_Table
# WHERE participant_code IN ('GW', 'MELK', 'AURICON')
#     AND status = 'Approved'
# GROUP BY description_of_outage
# ORDER BY description_of_outage)
#
# SELECT
# participant_code,
# facility_code,
# Total_Energy_Lost,
# Percent_Energy_Lost,
# description_of_outage,
# RANK () OVER (PARTITION BY description_of_outage) AS RANK
# FROM table_5
# ORDER BY Total_Energy_Lost DESC;
# Out:
#  * sqlite:///temp_db_file.db
# Done.
# [('GW', 'BW1_GREENWATERS_G2', 28687.54, 0.11338965199277169, 'Operational Issues caused real time forced outage.', 1),
#  ('AURICON', 'AURICON_PNJ_U1', 6033.87, 0.023849323416006575, 'Full unit trip', 1),
#  ('AURICON', 'AURICON_PNJ_U1', 3230.0, 0.012766817089811554, 'Routine Maintenance', 1),
#  ('AURICON', 'AURICON_PNJ_U1', 1573.0, 0.006217400396988723, 'Return to service from outage delayed', 1),
#  ('AURICON', 'AURICON_PNJ_U1', 1430.0, 0.005652182179080657, 'Blade wash', 1),
#  ('AURICON', 'AURICON_PNJ_U1', 1167.73, 0.0046155403468376615, 'unit maximum output was restricted to 100 MW as-generated due to high rotor temperature alarm for safety purposes', 1),
#  ('AURICON', 'AURICON_PNJ_U1', 1140.0, 0.004505935443462902, 'WGP U2 vibration issues during start-up sequence.', 1),
#  ('AURICON', 'AURICON_PNJ_U1', 1137.4, 0.004495658748591846, 'MBA TS81 line trip WWF curtailed', 1),
#  ('MELK', 'MELK_G7', 1100.0, 0.004347832445446659, 'Safety Issues', 1),
#  ('MELK', 'MELK_G7', 972.18, 0.0038426143152857574, 'Unit trip - loss of ignition at low load', 1),
#  ('MELK', 'MELK_G7', 954.22, 0.003771626069176465, 'Boiler inspection', 1),
#  ('AURICON', 'AURICON_PNJ_U1', 950.0, 0.003754946202885751, 'Routine maintenance', 1),
#  ('GW', 'BW1_GREENWATERS_G2', 936.0, 0.0036996101535800665, 'protection relay testing', 1),
#  ('MELK', 'MELK_G7', 893.72, 0.0035324952846768985, 'Weekend Outage', 1),
#  ('GW', 'BW1_GREENWATERS_G2', 833.6, 0.0032948664786584866, 'FO', 1),
#  ('MELK', 'MELK_G7', 791.0, 0.0031264867857711885, 'Boiler Outage', 1),
#  ('AURICON', 'AURICON_PNJ_U1', 760.0, 0.0030039569623086008, 'Bush fire resulting in faults to transmission lines. Consequential outage to be requested.', 1),
#  ('MELK', 'MELK_G7', 686.48, 0.002713363651954748, 'Rotary air heater wash', 1),
#  ('MELK', 'MELK_G7', 686.0, 0.002711466415978553, 'Reduced Load to allow for increased CW Temperature / Vacuum ', 1),
#  ('AURICON', 'AURICON_PNJ_U1', 676.94, 0.0026756560869278744, 'Unit slow to ramp up.', 1),
#  ('AURICON', 'AURICON_PNJ_U1', 666.0, 0.002632414916970432, 'Routine Water Wash', 1),
#  ('MELK', 'MELK_G7', 659.9, 0.0026083042097729547, 'Boiler Maintenance', 1),
#  ('GW', 'BW1_GREENWATERS_G2', 651.0, 0.0025731262927143413, 'BW1 annual statutory outage', 1),
#  ('AURICON', 'AURICON_PNJ_U1', 624.3, 0.002467592541538499, 'general maintenance', 1),
#  ('GW', 'BW1_GREENWATERS_G2', 624.0, 0.002466406769053378, 'OOM', 1),
#  ('MELK', 'MELK_G7', 622.8, 0.0024616636791128903, 'Pre Summer Outage', 1),
#  ('AURICON', 'AURICON_PNJ_U1', 616.17, 0.002435458107191698, 'Unit trip', 1),
#  ('MELK', 'MELK_G7', 585.0, 0.0023122563459875415, 'Cooling Tower Tie in', 1),
#  ('AURICON', 'AURICON_PNJ_U1', 583.7, 0.0023071179985520137, 'Western Power Networks outages on the MGA-MBA81 Transmission Line ', 1),
#  ('AURICON', 'AURICON_PNJ_U1', 564.53, 0.0022313471367527296, 'Unit RTS & ramp-up delayed due to reset of overspeed tripping solenoid.', 1),
#  ('AURICON', 'AURICON_PNJ_U1', 499.64, 0.001974864548220881, 'Wagerup unit 2 trip, control fault', 1),
#  ('MELK', 'MELK_G7', 486.0, 0.001920951425897342, 'Load Derate', 1),
#  ('GW', 'BW1_GREENWATERS_G2', 473.2, 0.0018703584665321446, 'FO due to unit trip', 1),
#  ('AURICON', 'AURICON_PNJ_U1', 472.19, 0.0018663663658322347, 'Pinjarra Unit 2 ramping up from an outage', 1),
#  ('GW', 'BW1_GREENWATERS_G2', 468.0, 0.0018498050767900333, 'PD testing', 1),
#  ('AURICON', 'AURICON_PNJ_U1', 460.4, 0.0018197655071669472, 'Limited output due to ambient conditions (High temperature)', 1),
#  ('MELK', 'MELK_G7', 454.0, 0.0017944690274843485, 'Cooling Tower Outage', 1),
#  ('MELK', 'MELK_G7', 438.0, 0.0017312278282778516, '1 Day Outage', 1),
#  ('GW', 'BW1_GREENWATERS_G2', 434.0, 0.0017154175284762273, 'BW1 annual statutory outage.  Full C-Inspection, Boiler Chemical Clean, Blade Feathering.\n', 1),
#  ('AURICON', 'AURICON_PNJ_U1', 429.0, 0.0016956546537241972, 'Combustion inspection', 1),
#  ('MELK', 'MELK_G7', 422.0, 0.0016679866290713547, 'Boiler Inspection', 1),
#  ('MELK', 'MELK_G7', 422.0, 0.0016679866290713547, 'Boiler Repairs', 1),
#  ('MELK', 'MELK_G7', 422.0, 0.0016679866290713547, 'Unit MFT/MTR', 1),
#  ('AURICON', 'AURICON_PNJ_U1', 419.99, 0.0016600419534210386, 'Pinjarra Unit 2 tripped due to blade path temperature deviation', 1),
#  ('MELK', 'MELK_G7', 416.9, 0.0016478284968242838, 'Delayed RTS', 1),
#  ('MELK', 'MELK_G7', 411.8, 0.001627670364577213, 'Boiler Inspection and repairs', 1),
#  ('MELK', 'MELK_G7', 411.8, 0.001627670364577213, 'Delayed Unit RTS.', 1),
#  ('MELK', 'MELK_G7', 411.8, 0.001627670364577213, 'Governor Control Issues.', 1),
#  ('MELK', 'MELK_G7', 411.8, 0.001627670364577213, 'NT91 Transmission Line Trip causing M6 Load Rejection/Trip', 1),
#  ('MELK', 'MELK_G7', 411.8, 0.001627670364577213, 'Turbine Ancillary Equipment Outage', 1),
#  ('MELK', 'MELK_G7', 411.8, 0.001627670364577213, 'Unit MTR.', 1),
#  ('MELK', 'MELK_G7', 411.8, 0.001627670364577213, 'Unit overhaul - Includes dual outage with M5', 1),
#  ('GW', 'BW1_GREENWATERS_G2', 390.0, 0.001541504230658361, 'ODOM', 1),
#  ('AURICON', 'AURICON_PNJ_U1', 384.4, 0.001519369810936087, 'Unit slow to ramp up', 1),
#  ('AURICON', 'AURICON_PNJ_U1', 380.0, 0.0015019784811543004, 'A-inspection outage extended', 1),
#  ('AURICON', 'AURICON_PNJ_U1', 380.0, 0.0015019784811543004, 'Compulsory work required by the regulator to upgrade the common gas skid on site.', 1),
#  ('AURICON', 'AURICON_PNJ_U1', 380.0, 0.0015019784811543004, 'Isolation valve drop test', 1),
#  ('AURICON', 'AURICON_PNJ_U1', 380.0, 0.0015019784811543004, 'Jacking, control and lube oil maintenance checks', 1),
#  ('AURICON', 'AURICON_PNJ_U1', 380.0, 0.0015019784811543004, 'Pre-outage maintenance prior to planned A-inspection outage in July ', 1),
#  ('AURICON', 'AURICON_PNJ_U1', 380.0, 0.0015019784811543004, 'Regular routine maintenance', 1),
#  ('AURICON', 'AURICON_PNJ_U1', 380.0, 0.0015019784811543004, 'Unit trip due to high combustion pulsation', 1),
#  ('AURICON', 'AURICON_PNJ_U1', 374.25, 0.0014792511751894656, 'WGP GT delayed ramp-up due to start failure.', 1),
#  ('AURICON', 'AURICON_PNJ_U1', 365.02, 0.0014427689083972178, 'Protective load shed trip', 1),
#  ('AURICON', 'AURICON_PNJ_U1', 362.4, 0.0014324131620271538, 'Operational issues caused real time forced outage.', 1),
#  ('GW', 'BW1_GREENWATERS_G2', 353.6, 0.0013976305024635807, 'Unit failed to start', 1),
#  ('GW', 'BW1_GREENWATERS_G2', 348.4, 0.001377077112721469, 'Unit tripped', 1),
#  ('AURICON', 'AURICON_PNJ_U1', 348.27, 0.0013765632779779162, 'PNJ U1 max output reduced due to ambient conditions.', 1),
#  ('MELK', 'MELK_G7', 347.78, 0.0013746265162522173, 'Full forced outage (pro-rata) due to loss of 330kV line from Shotts.', 1),
#  ('MELK', 'MELK_G7', 347.26, 0.0013725711772780062, 'Loss off fire to the boiler resulting in pressure drop', 1),
#  ('GW', 'BW1_GREENWATERS_G2', 344.0, 0.0013596857829396825, 'Unit 12 minor works', 1),
#  ('MELK', 'MELK_G7', 343.24, 0.001356681825977374, 'Delay in RTS from planned outage', 1),
#  ('MELK', 'MELK_G7', 343.24, 0.001356681825977374, 'Extension to air heater wash outage (#227046 & #227068)', 1),
#  ('MELK', 'MELK_G7', 343.24, 0.001356681825977374, 'Extension to air heater wash outage (#227046)', 1),
#  ('MELK', 'MELK_G7', 343.24, 0.001356681825977374, 'Forced full outage due to Air Compressor issues', 1),
#  ('MELK', 'MELK_G7', 343.24, 0.001356681825977374, 'Full forced outage due to boiler feed pump trip', 1),
#  ('MELK', 'MELK_G7', 343.24, 0.001356681825977374, 'Full forced outage due to loss of 330kV line from Shotts.', 1),
#  ('MELK', 'MELK_G7', 343.24, 0.001356681825977374, 'Full forced outage due to unit trip.', 1),
#  ('MELK', 'MELK_G7', 343.24, 0.001356681825977374, 'Full forced outage for RAH repairs', 1),
#  ('MELK', 'MELK_G7', 343.24, 0.001356681825977374, 'Full outage for SDCC repairs', 1),
#  ('MELK', 'MELK_G7', 343.24, 0.001356681825977374, 'Full outage for SDCC repairs - early start', 1),
#  ('MELK', 'MELK_G7', 343.24, 0.001356681825977374, 'Major planned outage for inspection and maintenance', 1),
#  ('MELK', 'MELK_G7', 343.24, 0.001356681825977374, 'Planned unit outage for rotary air heater wash and minor repairs', 1),
#  ('MELK', 'MELK_G7', 343.24, 0.001356681825977374, 'Unit trip due to hydraulic fault', 1),
#  ('MELK', 'MELK_G7', 343.24, 0.001356681825977374, 'Unit tripped - LP heater level', 1),
#  ('MELK', 'MELK_G7', 343.24, 0.001356681825977374, 'forced outage due to unit trip', 1),
#  ('GW', 'BW1_GREENWATERS_G2', 342.0, 0.0013517806330388704, 'Common Gas yard outage works', 1),
#  ('GW', 'BW1_GREENWATERS_G2', 342.0, 0.0013517806330388704, 'Gas Regulation issue', 1),
#  ('GW', 'BW1_GREENWATERS_G2', 342.0, 0.0013517806330388704, 'Governor edits and testing', 1),
#  ('GW', 'BW1_GREENWATERS_G2', 342.0, 0.0013517806330388704, 'SCADA outage to add new comms equipment', 1),
#  ('GW', 'BW1_GREENWATERS_G2', 342.0, 0.0013517806330388704, 'To Facilitate WPC outage at Neerabup Terminal (ENAR 254597)\n', 1),
#  ('GW', 'BW1_GREENWATERS_G2', 342.0, 0.0013517806330388704, 'To Facilitate WPC outage at Neerabup Terminal (ENAR 254597) - Extension Requested by WPC\n', 1),
#  ('MELK', 'MELK_G7', 339.69, 0.0013426501849034323, 'Temperature related issues on ramp up', 1),
#  ('AURICON', 'AURICON_PNJ_U1', 339.4, 0.0013415039381678147, 'MGA TS81 line planned outage WWF curtailed', 1),
#  ('MELK', 'MELK_G7', 320.0, 0.0012648239841299373, 'FD fan  clean ', 1),
#  ('MELK', 'MELK_G7', 320.0, 0.0012648239841299373, 'Partial forced outage due to precip fault', 1),
#  ('MELK', 'MELK_G7', 314.28, 0.0012422152554136146, 'Partial forced outage during turbine valve testing', 1),
#  ('GW', 'BW1_GREENWATERS_G2', 313.42, 0.0012388160409562655, 'Control system maint', 1),
#  ('AURICON', 'AURICON_PNJ_U1', 312.76, 0.0012362073414889975, 'WGP1 gas control valve erratic, unit offline to reset/restart', 1),
#  ('GW', 'BW1_GREENWATERS_G2', 312.0, 0.001233203384526689, 'Control system upgrade', 1),
#  ('GW', 'BW1_GREENWATERS_G2', 312.0, 0.001233203384526689, 'FSNL', 1),
#  ('GW', 'BW1_GREENWATERS_G2', 312.0, 0.001233203384526689, 'Gas compliance work', 1),
#  ('GW', 'BW1_GREENWATERS_G2', 312.0, 0.001233203384526689, 'Gas tight testing', 1),
#  ('MELK', 'MELK_G7', 312.0, 0.001233203384526689, 'Pro-rata forced outage: Unit trip during turbine valve testing', 1),
#  ('GW', 'BW1_GREENWATERS_G2', 312.0, 0.001233203384526689, 'Transformer HV testing', 1),
#  ('GW', 'BW1_GREENWATERS_G2', 312.0, 0.001233203384526689, 'Transformer testing', 1),
#  ('GW', 'BW1_GREENWATERS_G2', 312.0, 0.001233203384526689, 'Turbine inspection', 1),
#  ('GW', 'BW1_GREENWATERS_G2', 312.0, 0.001233203384526689, 'extension for control system upgrade', 1),
#  ('GW', 'BW1_GREENWATERS_G2', 312.0, 0.001233203384526689, 'inspect fuel nozzles', 1),
#  ('AURICON', 'AURICON_PNJ_U1', 309.64, 0.0012238753076437305, 'Plant failed to reach target due to operational issue.', 1),
#  ('AURICON', 'AURICON_PNJ_U1', 309.36, 0.001222768586657617, 'A 0MW Security Constraint was applied to ALINTA_WWF', 1),
#  ('AURICON', 'AURICON_PNJ_U1', 308.8, 0.0012205551446853894, 'HV equipment maintenance coinciding with maintenance of Tx line insulators on MGA - TS 81', 1),
#  ('AURICON', 'AURICON_PNJ_U1', 303.84, 0.0012009503729313753, 'Unit had problems ramping up and staying to min load', 1),
#  ('AURICON', 'AURICON_PNJ_U1', 298.5, 0.0011798436226962072, 'PNJ1 max output reduced due to ambient conditions.', 1),
#  ('MELK', 'MELK_G7', 297.47, 0.001175772470497289, 'Pro rata outage due to air compressor issues', 1),
#  ('MELK', 'MELK_G7', 297.47, 0.001175772470497289, 'Pro-rata forced outage delay in return to service', 1),
#  ('AURICON', 'AURICON_PNJ_U1', 296.04, 0.0011701202883182083, 'Output limited due to ambient condition.', 1),
#  ('MELK', 'MELK_G7', 295.62, 0.0011684602068390377, 'Full forced outage (pro-rata) due to boiler feed pump trip', 1),
#  ('AURICON', 'AURICON_PNJ_U1', 293.81, 0.0011613060461788027, 'Ambient temperature, capacity limit', 1),
#  ('AURICON', 'AURICON_PNJ_U1', 290.37, 0.001147709188349406, 'Unit slow to ramp on start up', 1),
#  ('MELK', 'MELK_G7', 287.58, 0.001136681504237773, 'Unit run back due to thermocouple fault.', 1),
#  ('AURICON', 'AURICON_PNJ_U1', 287.02, 0.0011344680622655456, 'Late ramp up', 1),
#  ('AURICON', 'AURICON_PNJ_U1', 286.0, 0.0011304364358161315, 'Energy Safe WA - Gas Inspector - Isolation Valves.', 1),
#  ('AURICON', 'AURICON_PNJ_U1', 286.0, 0.0011304364358161315, 'Unit is unavailable after tripping on return to service.\n', 1),
#  ('AURICON', 'AURICON_PNJ_U1', 286.0, 0.0011304364358161315, 'Water Wash', 1),
#  ('AURICON', 'AURICON_PNJ_U1', 286.0, 0.0011304364358161315, 'Water wash', 1),
#  ('AURICON', 'AURICON_PNJ_U1', 286.0, 0.0011304364358161315, 'Windows 7 Upgrade', 1),
#  ('MELK', 'MELK_G7', 285.0, 0.0011264838608657254, 'Cooling Tower Top Deck Clean', 1),
#  ('MELK', 'MELK_G7', 270.0, 0.0010671952366096346, 'Full outage for boiler inspection and maintenance', 1),
#  ('AURICON', 'AURICON_PNJ_U1', 267.8, 0.0010584995717187412, 'Deviation from commissioning test plan. Contractor tuning requirement\n', 1),
#  ('AURICON', 'AURICON_PNJ_U1', 266.56, 0.0010535983787802376, 'Unit ramping limited on return to service', 1),
#  ('MELK', 'MELK_G7', 266.0, 0.0010513849368080103, 'Boiler Tube Leak Repairs', 1),
#  ('AURICON', 'AURICON_PNJ_U1', 264.91, 0.0010470766301120679, 'Deviation during ramp up from outage', 1),
#  ('MELK', 'MELK_G7', 254.6, 0.0010063255823733813, 'High silica restriction', 1),
#  ('AURICON', 'AURICON_PNJ_U1', 251.62, 0.0009945469090211713, 'WGP U2 delayed ramp-up due to start failure.', 1),
#  ('AURICON', 'AURICON_PNJ_U1', 250.8, 0.0009913057975618385, 'PNJ U2 start up profile on return to service', 1),
#  ('MELK', 'MELK_G7', 249.9, 0.000987748480106473, 'Load limitation', 1),
#  ('AURICON', 'AURICON_PNJ_U1', 245.32, 0.0009696456868336131, 'Output reduced due to ambient conditions', 1),
#  ('AURICON', 'AURICON_PNJ_U1', 242.56, 0.0009587365799704924, 'Unit tripped due to blown fuse on blade pass temperature element', 1),
#  ('AURICON', 'AURICON_PNJ_U1', 232.3, 0.0009181831609793264, 'MGA MBA81 TL outage, WWF curtailed', 1),
#  ('MELK', 'MELK_G7', 231.0, 0.0009130448135437984, 'Load Reduction', 1),
#  ('MELK', 'MELK_G7', 227.0, 0.0008972345137421742, 'Boiler Internal Inspection', 1),
#  ('MELK', 'MELK_G7', 227.0, 0.0008972345137421742, 'Boiler Maintenance Outage', 1),
#  ('MELK', 'MELK_G7', 227.0, 0.0008972345137421742, 'Boiler inspection and repairs - amended by SM on Participant request', 1),
#  ('MELK', 'MELK_G7', 227.0, 0.0008972345137421742, 'Condenser Clean', 1),
#  ('MELK', 'MELK_G7', 227.0, 0.0008972345137421742, 'Condenser clean', 1),
#  ('MELK', 'MELK_G7', 227.0, 0.0008972345137421742, 'GSUT inspection', 1),
#  ('MELK', 'MELK_G7', 227.0, 0.0008972345137421742, 'M8 GSUT Inspection', 1),
#  ('MELK', 'MELK_G7', 227.0, 0.0008972345137421742, 'MFT / MTR', 1),
#  ('MELK', 'MELK_G7', 227.0, 0.0008972345137421742, 'Outage Extension', 1),
#  ('MELK', 'MELK_G7', 227.0, 0.0008972345137421742, 'Turbine inspection and repair Outage extension.', 1),
#  ('MELK', 'MELK_G7', 227.0, 0.0008972345137421742, 'Turbine inspection and repairs', 1),
#  ('MELK', 'MELK_G7', 227.0, 0.0008972345137421742, 'Unit overhaul - Extension', 1),
#  ('MELK', 'MELK_G7', 227.0, 0.0008972345137421742, 'Unit overhaul - Includes dual outage with M8', 1),
#  ('MELK', 'MELK_G7', 227.0, 0.0008972345137421742, 'Unit overhaul - includes dual outage with M7', 1),
#  ('MELK', 'MELK_G7', 227.0, 0.0008972345137421742, 'Unit unavailable for RTS.', 1),
#  ('MELK', 'MELK_G7', 227.0, 0.0008972345137421742, 'Unit unavailable for dispatch.', 1),
#  ('AURICON', 'AURICON_PNJ_U1', 220.03, 0.000869685066337844, 'Plant pulsation alarm issue', 1),
#  ('MELK', 'MELK_G7', 220.0, 0.0008695664890893319, 'Bunker conveyor concrete repairs', 1),
#  ('MELK', 'MELK_G7', 220.0, 0.0008695664890893319, 'Retirement pending deregistration.', 1),
#  ('MELK', 'MELK_G7', 220.0, 0.0008695664890893319, 'Stage AB 3.3kV Station Switchboard Maintenance', 1),
#  ('MELK', 'MELK_G7', 219.0, 0.0008656139141389258, 'Cooling Tower Maintenance', 1),
#  ('GW', 'BW1_GREENWATERS_G2', 217.0, 0.0008577087642381137, 'Annual Statutory Outage.  Boiler and GAH works.', 1),
#  ('GW', 'BW1_GREENWATERS_G2', 217.0, 0.0008577087642381137, 'BW1 annual statutory outage.', 1),
#  ('GW', 'BW1_GREENWATERS_G2', 217.0, 0.0008577087642381137, 'BW1 inspection and repair.', 1),
#  ('GW', 'BW1_GREENWATERS_G2', 217.0, 0.0008577087642381137, 'Gas Air Heater casing leak', 1),
#  ('GW', 'BW1_GREENWATERS_G2', 217.0, 0.0008577087642381137, 'Maintenance outage to do repairs on the units gas air heater.', 1),
#  ('GW', 'BW1_GREENWATERS_G2', 217.0, 0.0008577087642381137, "Outage to repair water leak in unit's boiler", 1),
#  ('GW', 'BW1_GREENWATERS_G2', 217.0, 0.0008577087642381137, 'Repair turbine MCV.', 1),
#  ('GW', 'BW1_GREENWATERS_G2', 217.0, 0.0008577087642381137, 'Repairs turbine MCV', 1),
#  ('MELK', 'MELK_G7', 215.0, 0.0008498036143373016, 'Repack FW v/v', 1),
#  ('MELK', 'MELK_G7', 215.0, 0.0008498036143373016, 'Unit MFT/MTR.', 1),
#  ('GW', 'BW1_GREENWATERS_G2', 213.2, 0.0008426889794265706, 'Kemerton_GT12 tripped on start\n', 1),
#  ('GW', 'BW1_GREENWATERS_G2', 213.2, 0.0008426889794265706, 'Kemerton_GT12 tripped on start triggering protection which affected Kemerton_GT11\n', 1),
#  ('MELK', 'MELK_G7', 211.11, 0.0008344280977802221, 'Delayed Return To service', 1),
#  ('MELK', 'MELK_G7', 211.11, 0.0008344280977802221, 'Opportune Maintenance ', 1),
#  ('MELK', 'MELK_G7', 211.0, 0.0008339933145356773, 'Boiler Feed Pump Maintenance', 1),
#  ('MELK', 'MELK_G7', 211.0, 0.0008339933145356773, 'Boiler repairs', 1),
#  ('MELK', 'MELK_G7', 211.0, 0.0008339933145356773, 'DA repairs', 1),
#  ('MELK', 'MELK_G7', 211.0, 0.0008339933145356773, 'Delayed Synchronisation.', 1),
#  ('MELK', 'MELK_G7', 211.0, 0.0008339933145356773, 'Feed P/P maintenance', 1),
#  ('MELK', 'MELK_G7', 211.0, 0.0008339933145356773, 'Major unit overhaul', 1),
#  ('MELK', 'MELK_G7', 211.0, 0.0008339933145356773, 'Major unit overhaul extension', 1),
#  ('MELK', 'MELK_G7', 211.0, 0.0008339933145356773, 'Outage to enable PA Duct repairs', 1),
#  ('MELK', 'MELK_G7', 211.0, 0.0008339933145356773, 'RTS Delayed', 1),
#  ('MELK', 'MELK_G7', 211.0, 0.0008339933145356773, 'RTS Delayed due to Western Power Isolator', 1),
#  ('MELK', 'MELK_G7', 211.0, 0.0008339933145356773, 'Unit MTR', 1),
#  ('MELK', 'MELK_G7', 211.0, 0.0008339933145356773, 'Unit out of service for Western Power ENAR268961', 1),
#  ('MELK', 'MELK_G7', 211.0, 0.0008339933145356773, 'repair sample line', 1),
#  ('MELK', 'MELK_G7', 210.0, 0.0008300407395852713, 'BFP Maintenance.', 1),
#  ('MELK', 'MELK_G7', 208.98, 0.0008260091131358571, 'Boiler drain line damage', 1),
#  ('MELK', 'MELK_G7', 208.98, 0.0008260091131358571, 'Delayed Unit RTS', 1),
#  ('MELK', 'MELK_G7', 208.98, 0.0008260091131358571, 'Delays in unit return to service post major outage', 1),
#  ('MELK', 'MELK_G7', 208.98, 0.0008260091131358571, 'Low control oil pressure trip', 1),
#  ('MELK', 'MELK_G7', 206.0, 0.0008142304397836471, 'Unit trip due to hydraulic fault. Pro-rata forced outage', 1),
#  ('MELK', 'MELK_G7', 205.9, 0.0008138351822886065, 'Furnace Ash Hopper maintenance', 1),
#  ('MELK', 'MELK_G7', 205.9, 0.0008138351822886065, 'Gov. repair work', 1),
#  ('MELK', 'MELK_G7', 205.9, 0.0008138351822886065, 'Master Fuel Trip, loss of fuel to feeder', 1),
#  ('MELK', 'MELK_G7', 205.9, 0.0008138351822886065, 'Precipitator repairs', 1),
#  ('MELK', 'MELK_G7', 205.9, 0.0008138351822886065, 'Unit Trip', 1),
#  ('MELK', 'MELK_G7', 205.9, 0.0008138351822886065, 'Unit delay RTS', 1),
#  ('MELK', 'MELK_G7', 205.9, 0.0008138351822886065, 'Weekend outage', 1),
#  ('MELK', 'MELK_G7', 200.0, 0.0007905149900812108, '3 Day Outage', 1),
#  ('MELK', 'MELK_G7', 200.0, 0.0007905149900812108, 'Hardwire trip fault', 1),
#  ('MELK', 'MELK_G7', 200.0, 0.0007905149900812108, 'Reduced Load', 1),
#  ('AURICON', 'AURICON_PNJ_U1', 196.85, 0.0007780643789874317, 'Routine inspection', 1),
#  ('MELK', 'MELK_G7', 196.63, 0.0007771948124983424, 'Master fuel trip', 1),
#  ('MELK', 'MELK_G7', 195.0, 0.0007707521153291805, 'Turbine CV Issue ', 1),
#  ('MELK', 'MELK_G7', 195.0, 0.0007707521153291805, 'Turbine CV Maintenance', 1),
#  ('AURICON', 'AURICON_PNJ_U1', 190.57, 0.0007532422082988816, 'Slow to ramp up', 1),
#  ('AURICON', 'AURICON_PNJ_U1', 190.0, 0.0007509892405771502, 'A-Inspection + Gen Robotic Inspection+ Filter Change ', 1),
#  ('AURICON', 'AURICON_PNJ_U1', 190.0, 0.0007509892405771502, 'A-inspection + Gen robotic inspection + filter change. Previous outage #228920 cancelled due to delays to WGPU1 outage completion', 1),
#  ('AURICON', 'AURICON_PNJ_U1', 190.0, 0.0007509892405771502, 'Battery charger fault discovered', 1),
#  ('AURICON', 'AURICON_PNJ_U1', 190.0, 0.0007509892405771502, 'Battery charger fault discovered.', 1),
#  ('AURICON', 'AURICON_PNJ_U1', 190.0, 0.0007509892405771502, 'Bush fire resulting in faults on transmission lines. Consequential outage to be requested.', 1),
#  ('AURICON', 'AURICON_PNJ_U1', 190.0, 0.0007509892405771502, 'Bush fire resulting to faults in transmission lines. Consequential outage to be requested.', 1),
#  ('AURICON', 'AURICON_PNJ_U1', 190.0, 0.0007509892405771502, 'Bush fire resulting to faults in transmission lines. Consequential outage to be requested. See outage 225609.', 1),
#  ('AURICON', 'AURICON_PNJ_U1', 190.0, 0.0007509892405771502, 'Extension of A-inspection outage', 1),
#  ('AURICON', 'AURICON_PNJ_U1', 190.0, 0.0007509892405771502, 'Extension of A-inspection outage workscope', 1),
#  ('AURICON', 'AURICON_PNJ_U1', 190.0, 0.0007509892405771502, 'Extension of outage #228336 due to unforeseen workscope overrun', 1),
#  ('AURICON', 'AURICON_PNJ_U1', 190.0, 0.0007509892405771502, 'Fault finding on the battery charger.', 1),
#  ('AURICON', 'AURICON_PNJ_U1', 190.0, 0.0007509892405771502, 'Investigate rotor temperature alarm', 1),
#  ('MELK', 'MELK_G7', 190.0, 0.0007509892405771502, 'Partial forced outage after unit runback caused by CW Pump trip', 1),
#  ('AURICON', 'AURICON_PNJ_U1', 190.0, 0.0007509892405771502, 'Pre-outage maintenance requirement prior to planned A-inspection outage in July', 1),
#  ('AURICON', 'AURICON_PNJ_U1', 190.0, 0.0007509892405771502, 'Routine Maintenance Outage extended - Sequence Release issue', 1),
#  ('AURICON', 'AURICON_PNJ_U1', 190.0, 0.0007509892405771502, 'Routine Water Wash (extension)', 1),
#  ('AURICON', 'AURICON_PNJ_U1', 190.0, 0.0007509892405771502, 'Routine maintenance outage overrun', 1),
#  ('AURICON', 'AURICON_PNJ_U1', 190.0, 0.0007509892405771502, 'The unit failed to start.\n', 1),
#  ('AURICON', 'AURICON_PNJ_U1', 190.0, 0.0007509892405771502, 'Transfer of Experion control system from Alcoa to Alinta', 1),
#  ('AURICON', 'AURICON_PNJ_U1', 190.0, 0.0007509892405771502, 'Transfer of the Experion control system from Alcoa to Alinta', 1),
#  ('AURICON', 'AURICON_PNJ_U1', 190.0, 0.0007509892405771502, 'Unable to meet dispatch instruction', 1),
#  ('AURICON', 'AURICON_PNJ_U1', 190.0, 0.0007509892405771502, 'Unable to meet dispatch instruction\n', 1),
#  ('AURICON', 'AURICON_PNJ_U1', 190.0, 0.0007509892405771502, 'Unable to reach dispatch target issued by Random Number Generator.', 1),
#  ('AURICON', 'AURICON_PNJ_U1', 190.0, 0.0007509892405771502, 'Unit failed to start.', 1),
#  ('AURICON', 'AURICON_PNJ_U1', 190.0, 0.0007509892405771502, 'WGP U2 not started due to uneconomic short run.', 1),
#  ('AURICON', 'AURICON_PNJ_U1', 190.0, 0.0007509892405771502, 'WGP U2 start fail due to fuel drain valve limit switch fault', 1),
#  ('AURICON', 'AURICON_PNJ_U1', 190.0, 0.0007509892405771502, 'Western Power is carrying Landwehr Terminal Maintenance which will result in unavailability ', 1),
#  ('AURICON', 'AURICON_PNJ_U1', 188.26, 0.0007441117601634437, 'Unit had problems ramping up to dispatch target', 1),
#  ('MELK', 'MELK_G7', 187.24, 0.0007400801337140296, 'Forced partial outage due to failure of CW pump.', 1),
#  ('AURICON', 'AURICON_PNJ_U1', 184.59, 0.0007296058100954535, 'Unit did not reach target', 1),
#  ('MELK', 'MELK_G7', 183.24, 0.0007242698339124053, 'ID fan bearing failure - output reduced to 160MW', 1),
#  ('MELK', 'MELK_G7', 183.24, 0.0007242698339124053, 'Partial forced outage due to CW pump trip.', 1),
#  ('MELK', 'MELK_G7', 180.0, 0.0007114634910730897, 'Forced outage: Unit trip during turbine valve testing', 1),
#  ('AURICON', 'AURICON_PNJ_U1', 177.33, 0.0007009101159555056, 'delayed synchronization due to failure of fuel drain valve close limit switch', 1),
#  ('MELK', 'MELK_G7', 175.08, 0.000692016822317092, 'condenser level trip', 1),
#  ('AURICON', 'AURICON_PNJ_U1', 174.9, 0.0006913053588260188, 'WWF curtailed to 0 MW by Western Power for the hardware update for the control system used for SCADA - transmission and generation.', 1),
#  ('MELK', 'MELK_G7', 173.82, 0.0006870365778795803, 'Main Fuel Trip due to wet coal', 1),
#  ('GW', 'BW1_GREENWATERS_G2', 172.0, 0.0006798428914698413, 'Minor Inspection outages', 1),
#  ('MELK', 'MELK_G7', 171.19, 0.0006766413057600123, 'Partial forced outage. 3 mill operation', 1),
#  ('GW', 'BW1_GREENWATERS_G2', 171.0, 0.0006758903165194352, 'One unit On the day outage request ', 1),
#  ('GW', 'BW1_GREENWATERS_G2', 171.0, 0.0006758903165194352, 'Opportunistic  outage for 171MW removed', 1),
#  ('GW', 'BW1_GREENWATERS_G2', 170.0, 0.0006719377415690291, 'Forced outage', 1),
#  ('AURICON', 'AURICON_PNJ_U1', 167.91, 0.0006636768599226805, 'Delayed synch due to breaker fault', 1),
#  ('GW', 'BW1_GREENWATERS_G2', 164.0, 0.0006482222918665928, 'Curtailment to 0MW at the request of Western Power', 1),
#  ('GW', 'BW1_GREENWATERS_G2', 164.0, 0.0006482222918665928, 'Power station curtailed to 0MW at the request of Western Power', 1),
#  ('GW', 'BW1_GREENWATERS_G2', 164.0, 0.0006482222918665928, 'Pressure safety valves testing and certification', 1),
#  ('AURICON', 'AURICON_PNJ_U1', 163.96, 0.0006480641888685767, 'Flame out trip during loading for capacity test', 1),
#  ('MELK', 'MELK_G7', 163.24, 0.0006452183349042842, 'Partial forced outage due to CW pump trip', 1),
#  ('MELK', 'MELK_G7', 163.24, 0.0006452183349042842, 'Partial outage for full stroke turbine valve testing', 1),
#  ('MELK', 'MELK_G7', 163.24, 0.0006452183349042842, 'Partial outage for precipitator internal maintenance', 1),
#  ('MELK', 'MELK_G7', 163.0, 0.0006442697169161867, 'Partial outage to allow internal access for precipitator repairs', 1),
#  ('AURICON', 'AURICON_PNJ_U1', 162.07, 0.0006405938222123092, 'Operational issues caused unit trip.', 1),
#  ('MELK', 'MELK_G7', 160.0, 0.0006324119920649686, 'Partial forced outage due to delay in RTS', 1),
#  ('AURICON', 'AURICON_PNJ_U1', 159.68, 0.0006311471680808387, 'Wagerup U1 slow to ramp due to plant issues', 1),
#  ('MELK', 'MELK_G7', 159.13, 0.0006289732518581153, 'Over-speed trip fault', 1),
#  ('AURICON', 'AURICON_PNJ_U1', 158.2, 0.0006252973571542376, 'PNJ U1 delayed return to service after outage', 1),
#  ('AURICON', 'AURICON_PNJ_U1', 157.88, 0.0006240325331701077, 'Delay in unit ramp-up', 1),
#  ('MELK', 'MELK_G7', 157.38, 0.0006220562456949047, 'Pro rata forced outage due to unit trip', 1),
#  ('AURICON', 'AURICON_PNJ_U1', 156.01, 0.0006166412180128485, 'Unit slow to ramp to dispatch target following unexpected direction to commit from System Management', 1),
#  ('GW', 'BW1_GREENWATERS_G2', 156.0, 0.0006166016922633445, 'Combustion chamber failed to fire.  Protection Shutdown.', 1),
#  ('GW', 'BW1_GREENWATERS_G2', 156.0, 0.0006166016922633445, 'Compliance testing', 1),
#  ('GW', 'BW1_GREENWATERS_G2', 156.0, 0.0006166016922633445, 'Control System Upgrade', 1),
#  ('GW', 'BW1_GREENWATERS_G2', 156.0, 0.0006166016922633445, 'Failed to start', 1),
#  ('GW', 'BW1_GREENWATERS_G2', 156.0, 0.0006166016922633445, 'HV maint', 1),
#  ('GW', 'BW1_GREENWATERS_G2', 156.0, 0.0006166016922633445, 'HV switching', 1),
#  ('GW', 'BW1_GREENWATERS_G2', 156.0, 0.0006166016922633445, 'Relay testing', 1),
#  ('GW', 'BW1_GREENWATERS_G2', 156.0, 0.0006166016922633445, 'Unit offline for WP switching', 1),
#  ('GW', 'BW1_GREENWATERS_G2', 156.0, 0.0006166016922633445, 'relay testing', 1),
#  ('MELK', 'MELK_G7', 155.9, 0.0006162064347683038, 'Unable to fire the boiler on coal.', 1),
#  ('AURICON', 'AURICON_PNJ_U1', 152.85, 0.0006041510811695654, 'fuel gas control valve issue', 1),
#  ('AURICON', 'AURICON_PNJ_U1', 152.25, 0.0006017795361993217, 'Issues with ramping up\n', 1),
#  ('AURICON', 'AURICON_PNJ_U1', 151.79, 0.0005999613517221349, 'Fuel valves issue', 1),
#  ('AURICON', 'AURICON_PNJ_U1', 148.29, 0.0005861273393957137, 'Unit did not meet target during ramp-up', 1),
#  ('AURICON', 'AURICON_PNJ_U1', 147.1, 0.0005814237752047305, 'Wind farm tripped', 1),
#  ('MELK', 'MELK_G7', 146.48, 0.0005789731787354788, 'Partial forced outage - Unit load restricted to 270MW.', 1),
#  ('AURICON', 'AURICON_PNJ_U1', 146.41, 0.0005786964984889504, 'Unit ramp-up', 1),
#  ('MELK', 'MELK_G7', 145.33, 0.0005744277175425118, 'Forced partial outage (pro-rata) due to failure of CW pump.', 1),
#  ('MELK', 'MELK_G7', 145.0, 0.0005731233678088778, '11 KV supply Protection Activated', 1),
#  ('AURICON', 'AURICON_PNJ_U1', 143.0, 0.0005652182179080658, 'Blade Wash', 1),
#  ('AURICON', 'AURICON_PNJ_U1', 143.0, 0.0005652182179080658, 'Bush fire resulting to tripping of tranmission lines. Consequential outage to be requested. See outage #225600', 1),
#  ('AURICON', 'AURICON_PNJ_U1', 143.0, 0.0005652182179080658, 'Bush fire resulting to tripping of transmission lines. Consequential outage to be requested. See outage 225603.', 1),
#  ('AURICON', 'AURICON_PNJ_U1', 143.0, 0.0005652182179080658, 'HRSG High Pressure Drum feed water isolation valves and motor operator valves (MOV) issues.', 1),
#  ('AURICON', 'AURICON_PNJ_U1', 143.0, 0.0005652182179080658, 'Major Inspection', 1),
#  ('AURICON', 'AURICON_PNJ_U1', 143.0, 0.0005652182179080658, 'PNJ U2 delayed return from Blade Wash Outage due to Steam Leak', 1),
#  ('AURICON', 'AURICON_PNJ_U1', 143.0, 0.0005652182179080658, 'Unit trip during RTS from blade wash outage', 1),
#  ('AURICON', 'AURICON_PNJ_U1', 143.0, 0.0005652182179080658, 'Unit trip on loss of 330 kV line due to bushfire', 1),
#  ('AURICON', 'AURICON_PNJ_U1', 143.0, 0.0005652182179080658, 'Unit tripped during startup coming from outage due to a HH alarm on IP drum level.', 1),
#  ('MELK', 'MELK_G7', 140.66, 0.0005559691925241155, 'HP Cylinder metal stress', 1),
#  ('AURICON', 'AURICON_PNJ_U1', 136.43, 0.0005392498004838979, 'Late synchronisation due to communications failure between the control room and the unit', 1),
#  ('AURICON', 'AURICON_PNJ_U1', 136.24, 0.0005384988112433208, 'unit slow to ramp up', 1),
#  ('AURICON', 'AURICON_PNJ_U1', 135.92, 0.0005372339872591908, 'Unit in commissioning. Ramping issue.', 1),
#  ('MELK', 'MELK_G7', 134.2, 0.0005304355583444924, 'ID fan bearing failure - output reduced to 160MW (pro-rata)', 1),
#  ('AURICON', 'AURICON_PNJ_U1', 133.8, 0.0005288545283643301, 'Late ramp up.', 1),
#  ('MELK', 'MELK_G7', 133.14, 0.0005262458288970619, 'LP Differential Expansion issue', 1),
#  ('AURICON', 'AURICON_PNJ_U1', 133.1, 0.0005260877258990458, 'WGP U2 shut down early - Email advice from Trading not received', 1),
#  ('AURICON', 'AURICON_PNJ_U1', 132.8, 0.000524901953413924, 'WWF Constrained due to high winds and risk of exceeding line overload limits.', 1),
#  ('AURICON', 'AURICON_PNJ_U1', 132.55, 0.0005239138096763225, 'Unit start-up profile operational requirement', 1),
#  ('MELK', 'MELK_G7', 132.5, 0.0005237161809288021, 'Electrical fault causing turbine trip. Delayed synchronisation. Gate Closure Violation.', 1),
#  ('AURICON', 'AURICON_PNJ_U1', 131.64, 0.0005203169664714528, 'Unit slow to ramp up. ', 1),
#  ('AURICON', 'AURICON_PNJ_U1', 131.23, 0.0005186964107417864, 'slow to ramp up', 1),
#  ('MELK', 'MELK_G7', 130.06, 0.0005140718980498113, 'Delay during synchronization', 1),
#  ('MELK', 'MELK_G7', 130.0, 0.000513834743552787, 'FD fan inspection and repairs', 1),
#  ('AURICON', 'AURICON_PNJ_U1', 128.09, 0.0005062853253975114, 'Bush fire resulting to tripping of transmission lines. Consequential outage to be requested. ', 1),
#  ('AURICON', 'AURICON_PNJ_U1', 127.63, 0.0005044671409203247, 'Bush fire resulting to tripping of transmission lines. Consequential outage to be requested. See outage 225600 and 225601.', 1),
#  ('MELK', 'MELK_G7', 126.11, 0.0004984592269957074, 'ID fan control limitation', 1),
#  ('AURICON', 'AURICON_PNJ_U1', 124.58, 0.0004924117873215862, 'Unit issues ramping up to dispatch target due to safety concern when high rotor temperature alarm got activated', 1),
#  ('GW', 'BW1_GREENWATERS_G2', 123.9, 0.0004897240363553101, 'No crane available Furnace 1 & 2. For further information contact Simcoa Furnace Control on 9780 6670', 1),
#  ('AURICON', 'AURICON_PNJ_U1', 122.08, 0.00048253034994557106, 'Unit restart, plant conditions preventing unit following ramp up profile', 1),
#  ('MELK', 'MELK_G7', 121.0, 0.00047826156899913254, 'BFP Maintenance', 1),
#  ('MELK', 'MELK_G7', 121.0, 0.00047826156899913254, 'Load reduction', 1),
#  ('AURICON', 'AURICON_PNJ_U1', 120.19, 0.0004750599832893036, 'Slow ramp up', 1),
#  ('MELK', 'MELK_G7', 120.0, 0.00047430899404872647, 'Load Limitation', 1),
#  ('MELK', 'MELK_G7', 120.0, 0.00047430899404872647, 'Partial maintenance outage - precip', 1),
#  ('AURICON', 'AURICON_PNJ_U1', 119.28, 0.0004714631400844341, 'Slow to ramp up, unit returning to service from outage\n', 1),
#  ('MELK', 'MELK_G7', 119.24, 0.00047130503708641785, 'Pro-rata partial forced outage. 3 mill operation', 1),
#  ('AURICON', 'AURICON_PNJ_U1', 117.22, 0.00046332083568659764, 'Pinjarra runback scheme', 1),
#  ('MELK', 'MELK_G7', 115.9, 0.00045810343675206167, 'Boiler feed pump failure', 1),
#  ('MELK', 'MELK_G7', 115.0, 0.0004545461192966962, 'Boiler inspection ', 1),
#  ('AURICON', 'AURICON_PNJ_U1', 114.87, 0.0004540322845531434, 'Unit tripped while ramping up to full load on return to service.\n', 1),
#  ('AURICON', 'AURICON_PNJ_U1', 112.79, 0.0004458109286562988, 'Bush fire resulting to tripping of transmission lines. Consequential outage to be requested. See outage 225603 and 225604', 1),
#  ('AURICON', 'AURICON_PNJ_U1', 111.42, 0.00044039590097424253, 'Unit slow to ramp up\n', 1),
#  ('AURICON', 'AURICON_PNJ_U1', 111.28, 0.0004398425404811857, 'Deviation from commissioning test plan. Stack emission testing requirement\n', 1),
#  ('MELK', 'MELK_G7', 111.0, 0.000438735819495072, 'Reduced Load for Mill Maintenance', 1),
#  ('AURICON', 'AURICON_PNJ_U1', 110.74, 0.00043770815000796637, 'high LP drum pressure as a result of the failure of the feedback arm from the IP to lp bled steam valve', 1),
#  ('MELK', 'MELK_G7', 110.0, 0.00043478324454466593, 'Additional partial outage (on top of #231444) for precipitator internal work.', 1),
#  ('MELK', 'MELK_G7', 110.0, 0.00043478324454466593, 'B Class Outage', 1),
#  ('MELK', 'MELK_G7', 110.0, 0.00043478324454466593, 'Cooling Tower Fan Repairs', 1),
#  ('MELK', 'MELK_G7', 110.0, 0.00043478324454466593, 'Internal Boiler Inspection', 1),
#  ('MELK', 'MELK_G7', 110.0, 0.00043478324454466593, 'Mill Maintenance', 1),
#  ('MELK', 'MELK_G7', 110.0, 0.00043478324454466593, 'Turbine auxiliary inspection ', 1),
#  ('MELK', 'MELK_G7', 109.5, 0.0004328069570694629, 'Under Voltage Relay Trip', 1),
#  ('AURICON', 'AURICON_PNJ_U1', 109.36, 0.00043225359657640607, 'Delayed RTS of the unit from blade wash', 1),
#  ('AURICON', 'AURICON_PNJ_U1', 108.28, 0.0004279848156299675, 'Ambient condition limitation', 1),
#  ('MELK', 'MELK_G7', 108.0, 0.00042687809464385384, 'Partial load restriction', 1),
#  ('AURICON', 'AURICON_PNJ_U1', 107.77, 0.0004259690024052604, 'Unit did not reach target due to unit trip.', 1),
#  ('MELK', 'MELK_G7', 103.83, 0.00041039585710066055, 'Pro-rata partial forced outage due to CW pump trip.', 1),
#  ('GW', 'BW1_GREENWATERS_G2', 103.0, 0.00040711521989182355, 'Unit 11 trip on gas detector failure', 1),
#  ('MELK', 'MELK_G7', 102.46, 0.00040498082941860426, 'Turbine limitation', 1),
#  ('MELK', 'MELK_G7', 102.22, 0.0004040322114305068, 'Mill trips took unit offline', 1),
#  ('AURICON', 'AURICON_PNJ_U1', 100.33, 0.00039656184477423936, 'Deviation from commissioning test plan. Contractor tuning requireme', 1),
#  ('MELK', 'MELK_G7', 100.0, 0.0003952574950406054, 'Feedwater restriction.', 1),
#  ('MELK', 'MELK_G7', 100.0, 0.0003952574950406054, 'Partial load reduction for minor maintenance', 1),
#  ('MELK', 'MELK_G7', 100.0, 0.0003952574950406054, 'Unavailability of plant', 1),
#  ('MELK', 'MELK_G7', 99.77, 0.000394348402802012, 'Loss of vacuum trip', 1),
#  ('MELK', 'MELK_G7', 98.89, 0.0003908701368456547, 'Mill trip', 1),
#  ('GW', 'BW1_GREENWATERS_G2', 98.8, 0.0003905144051001181, 'Kemerton_GT12 tripped on start triggering protection which affected Kemerton_GT11', 1),
#  ('GW', 'BW1_GREENWATERS_G2', 98.8, 0.0003905144051001181, 'Operational issue on start up', 1),
#  ('AURICON', 'AURICON_PNJ_U1', 98.26, 0.0003883800146268989, 'Unit did not reach target.', 1),
#  ('MELK', 'MELK_G7', 97.9, 0.0003869570876447527, 'Pro-rata Unit run back due to thermocouple fault.', 1),
#  ('AURICON', 'AURICON_PNJ_U1', 95.51, 0.00037751043351328225, 'Cold ambient temp, no high fogging permissives', 1),
#  ('AURICON', 'AURICON_PNJ_U1', 95.42, 0.0003771547017677457, 'Bushfire resulting to tripping of transmission lines. Consequential outage to be requested.', 1),
#  ('MELK', 'MELK_G7', 95.0, 0.0003754946202885751, 'Condenser and cooling tower performance', 1),
#  ('MELK', 'MELK_G7', 90.66, 0.00035834044500381284, 'Partial forced outage due to delay in RTS (pro-rata)', 1),
#  ('MELK', 'MELK_G7', 90.0, 0.00035573174553654485, 'Partial outage - load reduction from 270MW to 180MW', 1),
#  ('AURICON', 'AURICON_PNJ_U1', 89.14, 0.00035233253107919566, 'Unit shut down for outage.', 1),
#  ('AURICON', 'AURICON_PNJ_U1', 89.1, 0.00035217442808117936, 'Planned Western Power Networks outage on the MGA-TS81 Transmission Line', 1),
#  ('AURICON', 'AURICON_PNJ_U1', 89.1, 0.00035217442808117936, 'Planned Western Power Networks outage on the MGA_TS81 Transmission Line', 1),
#  ('AURICON', 'AURICON_PNJ_U1', 89.1, 0.00035217442808117936, 'Transformer 1 and 2 offline for HV maintenance', 1),
#  ('AURICON', 'AURICON_PNJ_U1', 89.1, 0.00035217442808117936, 'Unplanned outage of MGA-GTN line due to damaged insulators, WWF curtailed to 0 MW', 1),
#  ('AURICON', 'AURICON_PNJ_U1', 89.1, 0.00035217442808117936, 'WWF facility constrained to 0 MW due to System Management issue with PI servers', 1),
#  ('AURICON', 'AURICON_PNJ_U1', 89.1, 0.00035217442808117936, 'Western Power maintenance works on the MGA-GTN81 line', 1),
#  ('AURICON', 'AURICON_PNJ_U1', 89.1, 0.00035217442808117936, 'Western Power planned line outage on the MGA_TS81 line limiting WWF output', 1),
#  ('AURICON', 'AURICON_PNJ_U1', 89.1, 0.00035217442808117936, 'Western Power work at Mumbida substation, runback impacting Alinta Walkaway Windfarm', 1),
#  ('AURICON', 'AURICON_PNJ_U1', 88.59, 0.0003501586148564723, 'Slow ramp up from outage', 1),
#  ('AURICON', 'AURICON_PNJ_U1', 88.26, 0.00034885426512283835, 'Derating due to Ambient condition', 1),
#  ('GW', 'BW1_GREENWATERS_G2', 88.2, 0.00034861711062581397, 'Furnace 1 unplanned outage', 1),
#  ('AURICON', 'AURICON_PNJ_U1', 88.2, 0.00034861711062581397, 'Transformer 1 and Collector groups 1 to 3 offline for HV maintenance', 1),
#  ('AURICON', 'AURICON_PNJ_U1', 87.8, 0.0003470360806456515, 'Unit ramping up following RTS delay due to unit trip', 1),
#  ('AURICON', 'AURICON_PNJ_U1', 87.53, 0.0003459688854090419, 'Delay in unit ramp up', 1),
#  ('AURICON', 'AURICON_PNJ_U1', 87.45, 0.0003456526794130094, 'WWF tripped as runback scheme was invoked due to MBA - TS 81 line tripped. MBA TS 81 line tripped due to storms and lightning strikes in the North Country region. Information based on Dispatch Advisory 16400 and 16401 from Western Power.', 1),
#  ('AURICON', 'AURICON_PNJ_U1', 85.95, 0.00033972381698740037, 'Unit slow to ramp from previous dispatch due to power augmentation issues.', 1),
#  ('GW', 'BW1_GREENWATERS_G2', 82.0, 0.0003241111459332964, 'Both units having their Muscle Air Compressors serviced by an external contractor.', 1),
#  ('GW', 'BW1_GREENWATERS_G2', 82.0, 0.0003241111459332964, 'Both units to LOCAL control, run to Crank speed, turn engines and fuel over, no maintenance planned', 1),
#  ('MELK', 'MELK_G7', 82.0, 0.0003241111459332964, 'Cooling Tower Cell maintenance.', 1),
#  ('GW', 'BW1_GREENWATERS_G2', 82.0, 0.0003241111459332964, 'Crank test both units.', 1),
#  ('GW', 'BW1_GREENWATERS_G2', 82.0, 0.0003241111459332964, 'Curtailed to 0MW at the request of Western Power', 1),
#  ('GW', 'BW1_GREENWATERS_G2', 82.0, 0.0003241111459332964, 'Curtailed to 0MW at the request of Western Power.', 1),
#  ('GW', 'BW1_GREENWATERS_G2', 82.0, 0.0003241111459332964, 'External contractors replacing diesel return valves, plus run units to FSNL.', 1),
#  ('GW', 'BW1_GREENWATERS_G2', 82.0, 0.0003241111459332964, 'Full Speed No Load test run of the engines', 1),
#  ('GW', 'BW1_GREENWATERS_G2', 82.0, 0.0003241111459332964, 'GSU1 oil temp transducer replacement, GSU2 inspected at the same opportunity.', 1),
#  ('GW', 'BW1_GREENWATERS_G2', 82.0, 0.0003241111459332964, 'GT Muscle Air Compressor receiver inspection by external contractor. Taking the Muscle Air Compressors out of service takes the units out of availability.', 1),
#  ('GW', 'BW1_GREENWATERS_G2', 82.0, 0.0003241111459332964, 'GT control will be in LOCAL, Caterpillar diesel starter motor annual inspection with Westrac Tech, gas turbines run to FSNL for test.', 1),
#  ('GW', 'BW1_GREENWATERS_G2', 82.0, 0.0003241111459332964, 'GT1 and GT2 Boroscope with GE personnel in attendance.', 1),
#  ('GW', 'BW1_GREENWATERS_G2', 82.0, 0.0003241111459332964, 'GTG1 and GTG2 turbine inspections and fuel heater pre-winter inspection and test.', 1),
#  ('GW', 'BW1_GREENWATERS_G2', 82.0, 0.0003241111459332964, 'Gas Turbine muscle air compressor annual service by external contractor.', 1),
#  ('GW', 'BW1_GREENWATERS_G2', 82.0, 0.0003241111459332964, 'Gas Turbines to LOCAL control, run up to crank speed, packages inspected internally, returned to SOCC control.', 1),
#  ('GW', 'BW1_GREENWATERS_G2', 82.0, 0.0003241111459332964, 'Install upgrade cards in control system, and install replacement sensors in main transformer.', 1),
#  ('GW', 'BW1_GREENWATERS_G2', 82.0, 0.0003241111459332964, 'Intertrip from Western Power caused ME breaker 801.1 to open.  Intertrip as a result of a lightning storm in the area.  To be converted to a Consequential Outage.', 1),
#  ('GW', 'BW1_GREENWATERS_G2', 82.0, 0.0003241111459332964, 'Merredin PowerStation constrained to 0MW due to issues in WP switchyard.', 1),
#  ('GW', 'BW1_GREENWATERS_G2', 82.0, 0.0003241111459332964, 'Merredin powerstation unavailable due to CB failure at Muju terminal disrupting the 220KV line to eastern goldfields.\nDispatch Advisory ID 16868 ', 1),
#  ('GW', 'BW1_GREENWATERS_G2', 82.0, 0.0003241111459332964, 'Periodic maintenance - run to Crank speed only for the engines.', 1),
#  ('GW', 'BW1_GREENWATERS_G2', 82.0, 0.0003241111459332964, 'Place units in LOCAl control, run to Full Speed No Load for periodic testing - no maintenance is planned.', 1),
#  ('GW', 'BW1_GREENWATERS_G2', 82.0, 0.0003241111459332964, 'Place units into LOCAL control, run engines to FSNL, return to SOCC control.', 1),
#  ('GW', 'BW1_GREENWATERS_G2', 82.0, 0.0003241111459332964, 'Power Station curtailed to 0MW at the request of Western Power', 1),
#  ('GW', 'BW1_GREENWATERS_G2', 82.0, 0.0003241111459332964, 'Pressure safety valve testing and certiification', 1),
#  ('GW', 'BW1_GREENWATERS_G2', 82.0, 0.0003241111459332964, 'Replace a faulty network switch', 1),
#  ('GW', 'BW1_GREENWATERS_G2', 82.0, 0.0003241111459332964, 'Run both engines to FSNL for periodic schedule, no maintenance is planned.', 1),
#  ('GW', 'BW1_GREENWATERS_G2', 82.0, 0.0003241111459332964, 'Run units to FSNL for periodic routine.', 1),
#  ('GW', 'BW1_GREENWATERS_G2', 82.0, 0.0003241111459332964, 'Running the engines to Full Speed No Load for periodic testing - no maintenance is planned.', 1),
#  ('GW', 'BW1_GREENWATERS_G2', 82.0, 0.0003241111459332964, 'Starter motor & fire suppressant maintenance', 1),
#  ('GW', 'BW1_GREENWATERS_G2', 82.0, 0.0003241111459332964, 'Station 132kV breaker tripped due to 220kV line trip and WP Switching Program error', 1),
#  ('GW', 'BW1_GREENWATERS_G2', 82.0, 0.0003241111459332964, 'Units into LOCAL control, run up to FSNL, and returned to REMOTE when finished.\nNo maintenance is planned.', 1),
#  ('GW', 'BW1_GREENWATERS_G2', 82.0, 0.0003241111459332964, 'Units periodic test run to FSNL - no maintenance is planned.', 1),
#  ('GW', 'BW1_GREENWATERS_G2', 82.0, 0.0003241111459332964, 'Units placed in LOCAL control, run to FSNL, top up starter diesel fuel tanks, return to SOCC control.', 1),
#  ('GW', 'BW1_GREENWATERS_G2', 82.0, 0.0003241111459332964, 'Units placed into LOCAL control, engines run to FSNL only - no maintenance is planned.', 1),
#  ('GW', 'BW1_GREENWATERS_G2', 82.0, 0.0003241111459332964, 'Western Power Enar# 312727\nSupply power outage', 1),
#  ('GW', 'BW1_GREENWATERS_G2', 82.0, 0.0003241111459332964, 'forced outage due to western power ENAR309085', 1),
#  ('GW', 'BW1_GREENWATERS_G2', 82.0, 0.0003241111459332964, 'units unavailable to generate due to maintenance', 1),
#  ('AURICON', 'AURICON_PNJ_U1', 81.82, 0.0003233996824422233, 'Unit slow to ramp down before outage.', 1),
#  ('MELK', 'MELK_G7', 81.0, 0.0003201585709828904, 'Turbine LH ESV opening fault', 1),
#  ('MELK', 'MELK_G7', 80.0, 0.0003162059960324843, 'Full forced outage for RAH repairs (pro-rata)', 1),
#  ('MELK', 'MELK_G7', 80.0, 0.0003162059960324843, 'ID fan capacity', 1),
#  ('AURICON', 'AURICON_PNJ_U1', 79.25, 0.00031324156481967976, "Unit's output was constrained due to ventilation fan issues.", 1),
#  ('AURICON', 'AURICON_PNJ_U1', 79.2, 0.0003130439360721595, 'CG1 outage with Geraldton Feeder tripping', 1),
#  ('MELK', 'MELK_G7', 78.98, 0.00031217436958307017, 'FD fan control limitation', 1),
#  ('MELK', 'MELK_G7', 78.85, 0.0003116605348395173, 'Low furnace pressure due to loss of fuel supply', 1),
#  ('MELK', 'MELK_G7', 77.87, 0.0003077870113881194, 'Loss of temperature in the boiler', 1),
#  ('AURICON', 'AURICON_PNJ_U1', 77.59, 0.00030668029040200576, 'Unit slow to ramp from previous setpoint', 1),
#  ('AURICON', 'AURICON_PNJ_U1', 74.85, 0.00029585023503789313, 'Output from wind farm limited.', 1),
#  ('MELK', 'MELK_G7', 74.8, 0.0002956526062903728, 'ID fan bearing failure - Pro-rata load reduction to 160MW', 1),
#  ('AURICON', 'AURICON_PNJ_U1', 74.12, 0.00029296485532409676, 'Generator transformer issue and unit protection.', 1),
#  ('AURICON', 'AURICON_PNJ_U1', 74.11, 0.00029292532957459264, 'Unit ramping up following delayed RTS due to unit trip', 1),
#  ('AURICON', 'AURICON_PNJ_U1', 72.27, 0.0002856525916658455, 'Deviation after unit trip', 1),
#  ('AURICON', 'AURICON_PNJ_U1', 72.0, 0.00028458539642923586, 'Bush fire resulting to tripping of transmission lines. Consequential outage to be requested. See outage 225607.', 1),
#  ('GW', 'BW1_GREENWATERS_G2', 72.0, 0.00028458539642923586, 'Unit derate following load rejection event.', 1),
#  ('AURICON', 'AURICON_PNJ_U1', 71.21, 0.00028146286221841506, 'Slow to ramp up\n', 1),
#  ('MELK', 'MELK_G7', 70.0, 0.0002766802465284238, 'Partial outage (70MW) for mill maintenance', 1),
#  ('MELK', 'MELK_G7', 70.0, 0.0002766802465284238, 'Partial outage for mill maintenance ', 1),
#  ('MELK', 'MELK_G7', 70.0, 0.0002766802465284238, 'Pre-accepted outage for mill maintenance', 1),
#  ('MELK', 'MELK_G7', 69.0, 0.0002727276715780177, 'PA fan capacity', 1),
#  ('MELK', 'MELK_G7', 68.99, 0.00027268814582851364, 'Issue with feeder', 1),
#  ('AURICON', 'AURICON_PNJ_U1', 68.71, 0.00027158142484239994, 'High fogging system, PLC card failure', 1),
#  ('AURICON', 'AURICON_PNJ_U1', 67.72, 0.000267668375641498, 'Deviation from commissioning test plan. Stack emmission testing requirement and load swing\n', 1),
#  ('AURICON', 'AURICON_PNJ_U1', 67.67, 0.00026747074689397767, 'Unit unable to reach target due to ambient conditions.', 1),
#  ('MELK', 'MELK_G7', 65.43, 0.0002586169790050681, 'Wet Coal Issues', 1),
#  ('AURICON', 'AURICON_PNJ_U1', 65.05, 0.0002571150005239138, 'Unable to meet dispatch instruction.', 1),
#  ('AURICON', 'AURICON_PNJ_U1', 63.67, 0.00025166044709235344, 'Under generation - ambient conditions', 1),
#  ('AURICON', 'AURICON_PNJ_U1', 63.53, 0.0002511070865992966, 'Slow to ramp', 1),
# ...
#  ('GW', 'BW1_GREENWATERS_G2', 21.0, 8.300407395852713e-05, 'Blown hydraulic hose, Furnace 1. For further information contact Simcoa Furnace Control on 9780 6670', 1),
#  ('GW', 'BW1_GREENWATERS_G2', 21.0, 8.300407395852713e-05, 'Broken electrode. Kibble changeout. Furnace 1. For further information contact Simcoa Furnace Control on 9780 6670', 1),
#  ('GW', 'BW1_GREENWATERS_G2', 21.0, 8.300407395852713e-05, 'Casting crane failure. For further information contact Simcoa Furnace Control on 9780 6670', 1),
#  ('GW', 'BW1_GREENWATERS_G2', 21.0, 8.300407395852713e-05, 'Chain curtain drive fault', 1),
#  ('GW', 'BW1_GREENWATERS_G2', 21.0, 8.300407395852713e-05, 'Emergency generator caused hydraulic fault and demin water plant trip', 1),
#  ('GW', 'BW1_GREENWATERS_G2', 21.0, 8.300407395852713e-05, 'Flow meter problem on Line 35', 1),
#  ('GW', 'BW1_GREENWATERS_G2', 21.0, 8.300407395852713e-05, 'Fu1 Chain curtain fallen off.  For further information contact Simcoa Furnace Control on 9780 6670', 1),
#  ('GW', 'BW1_GREENWATERS_G2', 21.0, 8.300407395852713e-05, 'Fume duct issue', 1),
#  ('GW', 'BW1_GREENWATERS_G2', 21.0, 8.300407395852713e-05, 'Furnace 1 Outage', 1),
#  ('GW', 'BW1_GREENWATERS_G2', 21.0, 8.300407395852713e-05, 'Furnace 1 Phase 2 oil leak repair', 1),
#  ('GW', 'BW1_GREENWATERS_G2', 21.0, 8.300407395852713e-05, 'Furnace 1 water leak ? Transformer line 2. For further information contact Simcoa Furnace Control on 9780 6670', 1),
#  ('GW', 'BW1_GREENWATERS_G2', 21.0, 8.300407395852713e-05, 'Furnace 2 OOS', 1),
#  ('GW', 'BW1_GREENWATERS_G2', 21.0, 8.300407395852713e-05, 'Furnace 2 broken electrode phase 2. For further information contact Simcoa Furnace Control on 9780 6670', 1),
#  ('GW', 'BW1_GREENWATERS_G2', 21.0, 8.300407395852713e-05, 'Furnace 2. Dango tripped with stoking arm in the furnace. For further information contact Simcoa Furnace Control on 9780 6670', 1),
#  ('GW', 'BW1_GREENWATERS_G2', 21.0, 8.300407395852713e-05, 'Furnace off due to water leak on contact pad line - Furnace 2', 1),
#  ('GW', 'BW1_GREENWATERS_G2', 21.0, 8.300407395852713e-05, 'Furnace repairs', 1),
#  ('GW', 'BW1_GREENWATERS_G2', 21.0, 8.300407395852713e-05, 'Furnace1, Taphole repack.  For further information contact Simcoa Furnace Control on 9780 6670', 1),
#  ('GW', 'BW1_GREENWATERS_G2', 21.0, 8.300407395852713e-05, 'Hydraulic leak', 1),
#  ('GW', 'BW1_GREENWATERS_G2', 21.0, 8.300407395852713e-05, 'Hydraulic oil leak Phase 2 contact clamp', 1),
#  ('GW', 'BW1_GREENWATERS_G2', 21.0, 8.300407395852713e-05, 'Ladle car derailed, Furnace 1. For further information contact Simcoa Furnace Control on 9780 6670', 1),
#  ('GW', 'BW1_GREENWATERS_G2', 21.0, 8.300407395852713e-05, 'Launder failure and rebuild. For further information contact Simcoa Furnace Control on 9780 6670', 1),
#  ('GW', 'BW1_GREENWATERS_G2', 21.0, 8.300407395852713e-05, 'MCC fault', 1),
#  ('GW', 'BW1_GREENWATERS_G2', 21.0, 8.300407395852713e-05, 'Major Shutdown to reline furnace and overhaul furnace components.', 1),
#  ('GW', 'BW1_GREENWATERS_G2', 21.0, 8.300407395852713e-05, 'No water flow line 37 contact pad phase 2. For further information contact Simcoa Furnace Control on 9780 6670', 1),
#  ('GW', 'BW1_GREENWATERS_G2', 21.0, 8.300407395852713e-05, 'Oil Leak on Phase 2 .  For further information contact Simcoa Furnace Control on 9780 6670', 1),
#  ('GW', 'BW1_GREENWATERS_G2', 21.0, 8.300407395852713e-05, 'Oil leak', 1),
#  ('GW', 'BW1_GREENWATERS_G2', 21.0, 8.300407395852713e-05, 'Oil leak on ph1 furnace 1.  For further information contact Simcoa Furnace Control on 9780 6670', 1),
#  ('GW', 'BW1_GREENWATERS_G2', 21.0, 8.300407395852713e-05, 'Repair fuel oil lines', 1),
#  ('GW', 'BW1_GREENWATERS_G2', 21.0, 8.300407395852713e-05, 'Repair major water leak from pressure ring', 1),
#  ('GW', 'BW1_GREENWATERS_G2', 21.0, 8.300407395852713e-05, 'Repair to floor plate stoking floor, Furnace 2. For further information contact Simcoa Furnace Control on 9780 6670', 1),
#  ('GW', 'BW1_GREENWATERS_G2', 21.0, 8.300407395852713e-05, 'Repairs to chain curtain', 1),
#  ('GW', 'BW1_GREENWATERS_G2', 21.0, 8.300407395852713e-05, 'Replace fume duct onto feeder 203, Furnace 2. For further information contact Simcoa Furnace Control on 9780 6670', 1),
#  ('GW', 'BW1_GREENWATERS_G2', 21.0, 8.300407395852713e-05, 'Shutdown to , turn charge tube liners, Baghouse fan welding and chaincurtain maintenance etc to enable 2 year operation without major outage. (Includes Site Power Outage on 24/8/16)\n', 1),
#  ('GW', 'BW1_GREENWATERS_G2', 21.0, 8.300407395852713e-05, 'Taphole blow and repack, Furnace 1. For further information contact Simcoa Furnace Control on 9780 6670', 1),
#  ('GW', 'BW1_GREENWATERS_G2', 21.0, 8.300407395852713e-05, 'Taphole maintenance', 1),
#  ('GW', 'BW1_GREENWATERS_G2', 21.0, 8.300407395852713e-05, 'Taphole repair, Furnace1. For further information contact Simcoa Furnace Control on 9780 6670', 1),
#  ('GW', 'BW1_GREENWATERS_G2', 21.0, 8.300407395852713e-05, 'Tapping fan MCC fault', 1),
#  ('GW', 'BW1_GREENWATERS_G2', 21.0, 8.300407395852713e-05, 'Water leak Ph2 Fu1. For further information contact Simcoa Furnace Control on 9780 6670', 1),
#  ('GW', 'BW1_GREENWATERS_G2', 21.0, 8.300407395852713e-05, 'Water leak on hood', 1),
#  ('GW', 'BW1_GREENWATERS_G2', 21.0, 8.300407395852713e-05, 'Water leak on phase 1 pressure ring. For further information contact Simcoa Furnace Control on 9780 6670 ', 1),
#  ('GW', 'BW1_GREENWATERS_G2', 21.0, 8.300407395852713e-05, 'high current, incoming breaker faul', 1),
#  ('AURICON', 'AURICON_PNJ_U1', 20.97, 8.288549671001495e-05, 'delayed ramping due to ticking water valve that delayed the start of the power augmentation system', 1),
#  ('MELK', 'MELK_G7', 19.53, 7.719378878143023e-05, 'Pro-rata partial forced outage - Unit load restricted to 270MW from 18:52.', 1),
#  ('AURICON', 'AURICON_PNJ_U1', 19.21, 7.59289647973003e-05, 'PNJ U1 failed to meet dispatch target due to ramping.', 1),
#  ('AURICON', 'AURICON_PNJ_U1', 18.94, 7.486176956069067e-05, 'System management request to manually dispatch to 120 MW to facilitate circuit breaker re-gas work ', 1),
#  ('MELK', 'MELK_G7', 18.81, 7.434793481713787e-05, 'Pro-rata Partial forced outage. 3 mill operation', 1),
#  ('AURICON', 'AURICON_PNJ_U1', 18.71, 7.395267732209727e-05, 'Slow ramp rate due to power augmentation limitations', 1),
#  ('AURICON', 'AURICON_PNJ_U1', 18.68, 7.383410007358509e-05, 'slow to ramp up ', 1),
#  ('AURICON', 'AURICON_PNJ_U1', 18.52, 7.320168808152011e-05, 'Slow ramp up due to Blade Path Temperature control limit', 1),
#  ('GW', 'BW1_GREENWATERS_G2', 18.5, 7.3122636582512e-05, 'Furnace 2 - Taphole blow and repack ', 1),
#  ('AURICON', 'AURICON_PNJ_U1', 18.43, 7.284595633598357e-05, 'Evaporative cooler pump issues\n', 1),
#  ('AURICON', 'AURICON_PNJ_U1', 18.4, 7.272737908747139e-05, 'max output reduced due to ambient conditions.', 1),
#  ('MELK', 'MELK_G7', 18.24, 7.209496709540642e-05, 'Partial forced outage due to PF leak on mill. Unit reduced to three mill operation.', 1),
#  ('MELK', 'MELK_G7', 18.24, 7.209496709540642e-05, 'Partial forced outage due to mill failure. Reduced to three mill operation.', 1),
#  ('AURICON', 'AURICON_PNJ_U1', 17.41, 6.88143298865694e-05, 'Due to issues with the high fogging system', 1),
#  ('GW', 'BW1_GREENWATERS_G2', 17.0, 6.719377415690292e-05, 'Furnace 1, Large Flame and repack. For further information contact Simcoa Furnace Control on 9780 6670', 1),
#  ('GW', 'BW1_GREENWATERS_G2', 17.0, 6.719377415690292e-05, 'Start up curve, Furnace 1. For further information contact Simcoa Furnace Control on 9780 6670', 1),
#  ('MELK', 'MELK_G7', 16.93, 6.69170939103745e-05, 'loss of a cooling tower fan', 1),
#  ('GW', 'BW1_GREENWATERS_G2', 16.0, 6.324119920649687e-05, 'Derailed box cart', 1),
#  ('AURICON', 'AURICON_PNJ_U1', 15.1, 5.968388175113141e-05, 'Outage of collector group 3 due to suspected cable fault trip', 1),
#  ('MELK', 'MELK_G7', 15.08, 5.960483025212329e-05, 'operator was delayed in initiating ramp up', 1),
#  ('AURICON', 'AURICON_PNJ_U1', 15.0, 5.928862425609081e-05, 'CG1 outage', 1),
#  ('AURICON', 'AURICON_PNJ_U1', 15.0, 5.928862425609081e-05, 'CG4 outage.', 1),
#  ('MELK', 'MELK_G7', 15.0, 5.928862425609081e-05, 'High differential pressure in the baghouse', 1),
#  ('AURICON', 'AURICON_PNJ_U1', 14.85, 5.86957380135299e-05, 'Collector group 1 de-energised to allow turbine repairs', 1),
#  ('AURICON', 'AURICON_PNJ_U1', 14.85, 5.86957380135299e-05, 'Collector group 5 outage caused by failure of RMU on turbine 44.', 1),
#  ('AURICON', 'AURICON_PNJ_U1', 14.85, 5.86957380135299e-05, 'Collector group outage', 1),
#  ('AURICON', 'AURICON_PNJ_U1', 14.85, 5.86957380135299e-05, 'Collector group unavailable due to a cable fault', 1),
#  ('AURICON', 'AURICON_PNJ_U1', 14.85, 5.86957380135299e-05, 'Investigate and conduct reports on a turbine\n', 1),
#  ('AURICON', 'AURICON_PNJ_U1', 14.85, 5.86957380135299e-05, 'turbine fault', 1),
#  ('AURICON', 'AURICON_PNJ_U1', 14.07, 5.561272955221318e-05, 'Inlet temperature issues.', 1),
#  ('GW', 'BW1_GREENWATERS_G2', 14.0, 5.533604930568475e-05, '11MVar cap bank fault', 1),
#  ('GW', 'BW1_GREENWATERS_G2', 14.0, 5.533604930568475e-05, '11MVar cap bank fault ', 1),
#  ('MELK', 'MELK_G7', 14.0, 5.533604930568475e-05, 'Boiler capacity', 1),
#  ('MELK', 'MELK_G7', 13.9, 5.494079181064415e-05, 'Additional DI instructed within interval when unit was already ramping. Unable to comply.', 1),
#  ('MELK', 'MELK_G7', 13.78, 5.446648281659542e-05, 'issue with the baghouse', 1),
#  ('AURICON', 'AURICON_PNJ_U1', 13.77, 5.442695706709136e-05, 'Unit slow to ramp for capacity testing', 1),
#  ('AURICON', 'AURICON_PNJ_U1', 13.65, 5.395264807304264e-05, 'Unit unable to reach tartget due to ambient conditions', 1),
#  ('AURICON', 'AURICON_PNJ_U1', 13.61, 5.379454507502639e-05, 'Unit slow to ramp to full capacity during capacity testing', 1),
#  ('AURICON', 'AURICON_PNJ_U1', 13.24, 5.233209234337616e-05, 'Slow to ramp up.', 1),
#  ('GW', 'BW1_GREENWATERS_G2', 13.0, 5.13834743552787e-05, 'Merredin Energy curtailed to 69MW due to Western Power SCADA upgrade', 1),
#  ('MELK', 'MELK_G7', 11.9, 4.7035641909832044e-05, 'Mill A and Mill C starting faults', 1),
#  ('AURICON', 'AURICON_PNJ_U1', 11.88, 4.6956590410823925e-05, 'SM unintentionally applied a 0 MW constraint to WWF while troubleshooting dispatch system issues from earlier in the day', 1),
#  ('AURICON', 'AURICON_PNJ_U1', 11.35, 4.486172568710871e-05, 'Forced Outage', 1),
#  ('GW', 'BW1_GREENWATERS_G2', 11.3, 4.4664096939588414e-05, 'Launder failure Furnace 2. For further information contact Simcoa Furnace Control on 9780 6670', 1),
#  ('GW', 'BW1_GREENWATERS_G2', 11.0, 4.3478324454466596e-05, 'Shutdown for baghouse fans blanks.  For further information contact Simcoa Furnace Control on 9780 6670', 1),
#  ('GW', 'BW1_GREENWATERS_G2', 11.0, 4.3478324454466596e-05, 'Startup after shut for oil leak', 1),
#  ('AURICON', 'AURICON_PNJ_U1', 10.78, 4.260875796537726e-05, 'System Management request to manually dispatch to 120 MW to facilitate circuit breaker re-gas work', 1),
#  ('AURICON', 'AURICON_PNJ_U1', 10.3, 4.071152198918236e-05, 'PNJ U2 max output reduced due to ambient conditions.', 1),
#  ('MELK', 'MELK_G7', 10.0, 3.952574950406054e-05, 'Baghouse Issues', 1),
#  ('GW', 'BW1_GREENWATERS_G2', 10.0, 3.952574950406054e-05, 'Delay energising', 1),
#  ('MELK', 'MELK_G7', 10.0, 3.952574950406054e-05, 'Loss of a cooling tower fan', 1),
#  ('GW', 'BW1_GREENWATERS_G2', 10.0, 3.952574950406054e-05, 'Transformer 4 yearly maintenance', 1),
#  ('AURICON', 'AURICON_PNJ_U1', 9.2, 3.636368954373569e-05, 'Slow ramp up.', 1),
#  ('MELK', 'MELK_G7', 9.12, 3.604748354770321e-05, 'Pro-rata partial forced outage due to mill failure. Reduced to three mill operation for 15 minutes.', 1),
#  ('MELK', 'MELK_G7', 8.98, 3.5494123054646364e-05, 'Turbine vibrations', 1),
#  ('AURICON', 'AURICON_PNJ_U1', 8.87, 3.505933981010169e-05, 'Unit output below dispatch target due to ambient', 1),
#  ('MELK', 'MELK_G7', 8.0, 3.162059960324843e-05, 'West Boiler feed pump Outage', 1),
#  ('MELK', 'MELK_G7', 7.9, 3.1225342108207824e-05, 'operator was delayed in initiating ramp up ', 1),
#  ('MELK', 'MELK_G7', 7.48, 2.9565260629037285e-05, 'Loss of a mill', 1),
#  ('AURICON', 'AURICON_PNJ_U1', 7.06, 2.790517914986674e-05, 'unit derating', 1),
#  ('MELK', 'MELK_G7', 7.0, 2.7668024652842376e-05, 'Boiler feed pump, condenser and cooling tower performance', 1),
#  ('MELK', 'MELK_G7', 6.82, 2.695656116176929e-05, 'Coal feeder swap', 1),
#  ('MELK', 'MELK_G7', 6.74, 2.6640355165736802e-05, 'Coal issue', 1),
#  ('MELK', 'MELK_G7', 6.12, 2.418975869648505e-05, 'Mill Issue', 1),
#  ('AURICON', 'AURICON_PNJ_U1', 6.02, 2.3794501201444442e-05, 'Slow to ramp. Output limited due to ambient conditions.', 1),
#  ('GW', 'BW1_GREENWATERS_G2', 6.0, 2.3715449702436323e-05, 'Fan 13 off line due to maintenance work. For further information contact Simcoa Furnace Control on 9780 6670', 1),
#  ('AURICON', 'AURICON_PNJ_U1', 5.82, 2.3003986211363235e-05, 'Limited output due to ambient conditions', 1),
#  ('MELK', 'MELK_G7', 5.0, 1.976287475203027e-05, 'Baghouse issue resulting in restricted load', 1),
#  ('MELK', 'MELK_G7', 5.0, 1.976287475203027e-05, 'Baghouse issue resulting in restricted load\n', 1),
#  ('GW', 'BW1_GREENWATERS_G2', 5.0, 1.976287475203027e-05, 'ladle car derailment', 1),
#  ('MELK', 'MELK_G7', 4.72, 1.8656153765916574e-05, 'Rotary Air Heater seals', 1),
#  ('MELK', 'MELK_G7', 4.26, 1.683796928872979e-05, 'Pro-rata partial forced outage due to PF leak on mill. Unit reduced to three mill operation.', 1),
#  ('MELK', 'MELK_G7', 4.0, 1.5810299801624216e-05, 'Boiler feedpump capacity', 1),
#  ('MELK', 'MELK_G7', 4.0, 1.5810299801624216e-05, 'North Boiler feed pump oil leak', 1),
#  ('MELK', 'MELK_G7', 4.0, 1.5810299801624216e-05, 'Turbine control limitations', 1),
#  ('MELK', 'MELK_G7', 4.0, 1.5810299801624216e-05, 'Turbine limitations', 1),
#  ('GW', 'BW1_GREENWATERS_G2', 2.43, 9.604757129486712e-06, 'Due to WP works on the feeder line (ENAR 288079), the windfarm was required to be isolated for the duration of the works between 7:30am and 2 pm on 19/11/2016. The turbines were curtailed to 0 MV output around 7:20 am and restarted around 2:15 pm. ', 1),
#  ('GW', 'BW1_GREENWATERS_G2', 2.43, 9.604757129486712e-06, 'Due to planned WP works in the MB substation on 13 October 2016(REF ? ENAR 282428) the windfarm was curtailed to 0 output at 7:44 am and restarted at 5:15 pm', 1),
#  ('GW', 'BW1_GREENWATERS_G2', 2.43, 9.604757129486712e-06, 'The windfarm tripped around 7:25 am due to a fault at the Albany substation. The windfarm was put back into operation after the fault was cleared, around 10:55am', 1),
#  ('GW', 'BW1_GREENWATERS_G2', 2.43, 9.604757129486712e-06, 'Windfarm Output curtailed to 0MW during WP Scada upgrade on 14/5/2016', 1),
#  ('GW', 'BW1_GREENWATERS_G2', 2.43, 9.604757129486712e-06, 'Windfarm trip due to Network disturbance on Mt Barker Feeder', 1),
#  ('GW', 'BW1_GREENWATERS_G2', 2.43, 9.604757129486712e-06, 'Windfarm tripped at full output around 5:25pm due to a fault in the WP MB Substation Scada. WP restored Scada and windfarm was restarted around 5.55 pm ', 1),
#  ('GW', 'BW1_GREENWATERS_G2', 2.43, 9.604757129486712e-06, 'Windfarm was curtailed to 0MW due to WP works  starting 7 am; windfarm was restarted approx. 6:45 pm', 1),
#  ('GW', 'BW1_GREENWATERS_G2', 2.1, 8.300407395852713e-06, 'No crane available Furnace 1. For further information contact Simcoa Furnace Control on 9780 6670', 1),
#  ('AURICON', 'AURICON_PNJ_U1', 1.0, 3.952574950406054e-06, 'Reduced generation capability', 1),
#  ('MELK', 'MELK_G7', 0.0, 0.0, 'Commissioning ', 1),
#  ('GW', 'BW1_GREENWATERS_G2', 0.0, 0.0, 'Gas Regulation Train upgrade', 1),
#  ('GW', 'BW1_GREENWATERS_G2', 0.0, 0.0, 'Gas Regulation Train upgrade - Commissioning Test Plan', 1),
#  ('GW', 'BW1_GREENWATERS_G2', 0.0, 0.0, 'Governor testing', 1),
#  ('GW', 'BW1_GREENWATERS_G2', 0.0, 0.0, 'Maintenance Shutdown - Total power used 0MW as Furnace 1 is still shutdown', 1),
#  ('MELK', 'MELK_G7', 0.0, 0.0, 'Mill minor maintenance', 1),
#  ('MELK', 'MELK_G7', 0.0, 0.0, 'Precipitator Isokinetic and Efficiency Testing', 1)]

# %% [markdown]
# <h3 style = "color:#5D3FD3"> Expected Output (Sample) </h3>

# %%
# Out:
#  * sqlite:///AEMR.db
# Done.
# [('AURICON', 'AURICON_PNJ_U1', 'Full unit trip', 6033.87, 3.96, 1),
#  ('GW', 'BW1_GREENWATERS_G2', 'Operational Issues caused real time forced outage.', 28687.54, 18.84, 1),
#  ('MELK', 'MELK_G7', 'Safety Issues', 1100.0, 0.72, 1)]

# %% [markdown]
# Well done! That's a Wrap! We've now analyzed all the data we need to answer Management's Question.
# You'll now move to the next part of your analysis where you'll be proceeding with creating your story in Tableau using the insights you've gathered from your SQL Analysis!
#
# Let's now switch to Part II of our Analysis in Tableau!!
#
# <img src = https://www.energymagazine.com.au/wp-content/uploads/2021/05/shutterstock_1888482466-e1620278098312.jpg>

# %% [markdown]
# ## Appendix: SQL Cheat Sheet
#
# **SELECT**
#
# ```SQL
# - SELECT * FROM table_name -- Select all columns from a table
# - SELECT column_name(s) FROM table_name -- Select some columns from a table
# - SELECT DISTINCT column_name(s) FROM table_name -- Select only the different values
# - SELECT column_name(s) FROM table_name -- Select data filtered with the WHERE clause
#   WHERE condition
# - SELECT column_name(s) FROM table_name -- Order data by multiple columns. DESC for descending
#   ORDER BY column_1, column_2 DESC, column_3 ASC -- and ASC (optional) for ascending order
# ```
#
# **Operators**
# - `<` - Less than
# - `>` - Greater than
# - `<=` - Less than or equal
# - `>=` - Greater than or equal
# - `<>` - Not equal
# - `=` - Equal
# - `BETWEEN v1 AND v2` - Between a specified range
# - `LIKE` - Search pattern. Use `%` as a wildcard. E.g., `%o%` matches "o", "bob", "blob", etc.
#
# **Aggregate Functions**
# - `AVG(column)` - Returns the average value of a column
# - `COUNT(column)` - Returns the number of rows (without a NULL value) of a column
# - `MAX(column)` - Returns the maximum value of a column
# - `MIN(column)` - Returns the minimum value of a column
# - `SUM(column)` - Returns the sum of a column
# ```SQL
# SELECT AVG(column_name), MIN(column_name), MAX(column_name) FROM table_name
# ```
#
# **Miscellaneous**
# - `CASE...END` - Used in `SELECT` queries to alter a variable in place. E.g.
# ```SQL
# SELECT column_name
#     CASE
#         WHEN column_name >= 0 THEN 'POSITIVE'
#         ELSE 'NEGATIVE'
#     END
# FROM table
# ```
# - `AS` - Used to rename a variable. E.g.
# ```SQL
# SELECT SUM(column_name) AS total_column_name FROM table_name
# ```
# - `GROUP BY` - Used to group rows that share the same value(s) in particular column(s). It is mostly used along with aggregation functions
# - `ORDER BY` - Determines the order in which the rows are returned by an SQL query
